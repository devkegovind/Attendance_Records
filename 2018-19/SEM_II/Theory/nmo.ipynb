# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("D:\Downloads\TE-3_18_19.xlsx")
df
# Out:
#     ROLL NO                 NAME OF STUDENTS
# 0         1          NANGARE ABHISHEK TANAJI
# 1         2          MAHAJAN ADITYA RAJENDRA
# 2         3          MORADE AJINKYA RAJENDRA
# 3         4          SAUDAGAR AVINASH DAGADU
# 4         5            PATIL DHANANJAY SUNIL
# 5         6              ADHAV SAYALI SANJAY
# 6         7             SHINDE NIKHIL SHARAD
# 7         8           SHARMA NISHANK SANTOSH
# 8         9        GAJAKOSH NITESH TULSHIRAM
# 9        10               KOKARE OMKAR ASHOK
# 10       11            YADAV OMKAR BABASAHEB
# 11       12  KULKARNI PRATHAMESH BHALCHANDRA
# 12       13          PATIL PRITESH PRABHAKAR
# 13       14              SHETE SAIRAJ SHARAD
# 14       15          PANASKAR SANDESH SURESH
# 15       16         SHINDE SAURABH BADASHAHA
# 16       17    ABHISHEK SHRIKRUSHNA MADANKAR
# 17       18             MAGAR SHUBHAM DEEPAK
# 18       19            PATIL SHUBHAM SHIVAJI
# 19       20           DHUMAL SIDDHESH DHUMAL
# 20       21            WADKAR SMITHIL MARUTI
# 21       22             GAIKWAD SURAJ BHARAT
# 22       23        BASVEKAR MUKESH BADRINATH
# 23       24         SHUBHAM SHAILENDRA BOLLA
# 24       25            DESHMANE ANIKET ASHOK
# 25       26             DHAVALE SEJAL ANKUSH
# 26       27              GAIKWAD ANIKET RAJU
# 27       28                HARIP AMOGH SUHAS
# 28       29      SARVADE ABHIJEET SHATRUGHNA
# 29       30            JAISWAL SHUBHAM VIJAY
# 30       31             KAKADE DIVYA VISHWAS
# 31       32             KARAD BALAJI SITARAM
# 32       33           LOHAR SAMIKSHA SANTOSH
# 33       34        CHOUDHARY MAMATA SHIVSGAR
# 34       35             SHIVADE DIPAK CHHOTU
# 35       36          WAGHMARE PRAJWAL KISHOR
# 36       37           MULGE MAHADEV CHENNAPA
# 37       38           JAGADALE AKSHAY SANJAY
# 38       39             SARPE MUKESH PRADEEP
# 39       40         DHERE BHOOSHAN PAMESHWAR

# %%
df['NAME OF STUDENTS'] = [i.title() for i in df['NAME OF STUDENTS']]

# %%
df.head()
# Out:
#    ROLL NO         NAME OF STUDENTS
# 0        1  Nangare Abhishek Tanaji
# 1        2  Mahajan Aditya Rajendra
# 2        3  Morade Ajinkya Rajendra
# 3        4  Saudagar Avinash Dagadu
# 4        5    Patil Dhananjay Sunil

# %%
df.to_csv("roll_call.csv")

# %%
df.shape
# Out:
# (40, 2)

# %% [markdown]
# **SEMESTER THEORY ATTENDANCE**

# %%
import random
import pandas as pd
import numpy as np
import datetime
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

def te_students_attendance31(n, start_date, end_date):
    
    students = range(n)
    
    cal = USFederalHolidayCalendar()
    holidays = cal.holidays(start=start_date, end=end_date)
    
    custom_business_day = CustomBusinessDay(weekmask='Mon Tue Thu Fri', holidays=holidays)

    date_range = pd.date_range(start=start_date, end=end_date, freq=custom_business_day)
    
    attendance_records1 = {}
    
    for student in students:
        attendance_records1[student] = []
        
        for day in date_range:
            attendance_records1[student].append('P' if random.random() < 0.85 else 'A')
                
    df = pd.DataFrame.from_dict(attendance_records1, orient='index', columns=date_range)
    df['Present'] = df.apply(lambda x: x[x == 'P'].count(), axis=1)
    df['Absent'] = df.apply(lambda x: x[x == 'A'].count(), axis=1)
    df['%Att'] = round(df['Present'] / len(date_range) * 100,2)
    df['UT1'] = [random.randint(10,30) for i in range(0,n)]
    df['PREL'] = [random.randint(26, 65) for i in range(0, n)]
     
    return df

# %%
sem_att = pd.concat([df, te_students_attendance31(40, '2018-12-24', '2019-03-19')], axis = 1)
sem_att.to_csv("Sem_att.csv")

# %%
sem_att
# Out:
#     ROLL NO                 NAME OF STUDENTS 2018-12-24 00:00:00
# 0         1          Nangare Abhishek Tanaji                   A  \
# 1         2          Mahajan Aditya Rajendra                   P
# 2         3          Morade Ajinkya Rajendra                   P
# 3         4          Saudagar Avinash Dagadu                   P
# 4         5            Patil Dhananjay Sunil                   P
# 5         6              Adhav Sayali Sanjay                   P
# 6         7             Shinde Nikhil Sharad                   P
# 7         8           Sharma Nishank Santosh                   P
# 8         9        Gajakosh Nitesh Tulshiram                   P
# 9        10               Kokare Omkar Ashok                   P
# 10       11            Yadav Omkar Babasaheb                   P
# 11       12  Kulkarni Prathamesh Bhalchandra                   P
# 12       13          Patil Pritesh Prabhakar                   P
# 13       14              Shete Sairaj Sharad                   P
# 14       15          Panaskar Sandesh Suresh                   P
# 15       16         Shinde Saurabh Badashaha                   P
# 16       17    Abhishek Shrikrushna Madankar                   A
# 17       18             Magar Shubham Deepak                   A
# 18       19            Patil Shubham Shivaji                   A
# 19       20           Dhumal Siddhesh Dhumal                   A
# 20       21            Wadkar Smithil Maruti                   P
# 21       22             Gaikwad Suraj Bharat                   P
# 22       23        Basvekar Mukesh Badrinath                   P
# 23       24         Shubham Shailendra Bolla                   P
# 24       25            Deshmane Aniket Ashok                   P
# 25       26             Dhavale Sejal Ankush                   P
# 26       27              Gaikwad Aniket Raju                   P
# 27       28                Harip Amogh Suhas                   P
# 28       29      Sarvade Abhijeet Shatrughna                   P
# 29       30            Jaiswal Shubham Vijay                   A
# 30       31             Kakade Divya Vishwas                   P
# 31       32             Karad Balaji Sitaram                   P
# 32       33           Lohar Samiksha Santosh                   P
# 33       34        Choudhary Mamata Shivsgar                   P
# 34       35             Shivade Dipak Chhotu                   P
# 35       36          Waghmare Prajwal Kishor                   P
# 36       37           Mulge Mahadev Chennapa                   P
# 37       38           Jagadale Akshay Sanjay                   P
# 38       39             Sarpe Mukesh Pradeep                   A
# 39       40         Dhere Bhooshan Pameshwar                   P
#
#    2018-12-27 00:00:00 2018-12-28 00:00:00 2018-12-31 00:00:00
# 0                    P                   P                   P  \
# 1                    P                   A                   P
# 2                    A                   P                   P
# 3                    P                   A                   P
# 4                    A                   P                   P
# 5                    P                   P                   P
# 6                    P                   P                   P
# 7                    P                   P                   P
# 8                    P                   P                   P
# 9                    P                   P                   P
# 10                   A                   P                   A
# 11                   P                   A                   P
# 12                   P                   P                   P
# 13                   P                   P                   P
# 14                   P                   A                   P
# 15                   P                   A                   P
# 16                   P                   P                   P
# 17                   P                   P                   P
# 18                   P                   P                   P
# 19                   P                   P                   A
# 20                   P                   P                   P
# 21                   P                   P                   P
# 22                   P                   P                   P
# 23                   P                   P                   P
# 24                   A                   P                   P
# 25                   P                   P                   P
# 26                   P                   P                   P
# 27                   A                   P                   A
# 28                   P                   P                   P
# 29                   P                   P                   P
# 30                   P                   P                   A
# 31                   P                   P                   P
# 32                   P                   P                   P
# 33                   A                   P                   P
# 34                   P                   P                   P
# 35                   P                   P                   P
# 36                   A                   P                   A
# 37                   P                   P                   P
# 38                   P                   P                   P
# 39                   P                   P                   P
#
#    2019-01-03 00:00:00 2019-01-04 00:00:00 2019-01-07 00:00:00
# 0                    P                   P                   P  \
# 1                    P                   P                   P
# 2                    P                   P                   A
# 3                    P                   P                   P
# 4                    P                   P                   P
# 5                    P                   P                   A
# 6                    P                   P                   P
# 7                    P                   P                   P
# 8                    A                   P                   A
# 9                    P                   P                   P
# 10                   P                   P                   P
# 11                   P                   A                   P
# 12                   P                   P                   A
# 13                   P                   P                   P
# 14                   P                   A                   A
# 15                   A                   P                   P
# 16                   P                   P                   P
# 17                   A                   P                   P
# 18                   P                   A                   P
# 19                   P                   P                   P
# 20                   P                   P                   A
# 21                   P                   P                   P
# 22                   P                   P                   P
# 23                   P                   P                   P
# 24                   P                   P                   P
# 25                   P                   P                   P
# 26                   P                   A                   P
# 27                   P                   P                   P
# 28                   P                   A                   P
# 29                   P                   P                   A
# 30                   P                   P                   P
# 31                   A                   P                   P
# 32                   P                   P                   P
# 33                   P                   P                   P
# 34                   P                   P                   P
# 35                   P                   A                   P
# 36                   P                   A                   P
# 37                   P                   P                   P
# 38                   P                   P                   P
# 39                   P                   A                   P
#
#    2019-01-08 00:00:00  ... 2019-03-12 00:00:00 2019-03-14 00:00:00
# 0                    P  ...                   P                   P  \
# 1                    P  ...                   P                   P
# 2                    A  ...                   P                   P
# 3                    P  ...                   P                   P
# 4                    P  ...                   A                   P
# 5                    P  ...                   P                   P
# 6                    P  ...                   P                   P
# 7                    P  ...                   A                   P
# 8                    P  ...                   P                   P
# 9                    P  ...                   P                   P
# 10                   A  ...                   P                   P
# 11                   A  ...                   P                   P
# 12                   P  ...                   P                   P
# 13                   P  ...                   P                   P
# 14                   P  ...                   P                   P
# 15                   P  ...                   P                   P
# 16                   P  ...                   P                   P
# 17                   A  ...                   P                   A
# 18                   P  ...                   P                   P
# 19                   P  ...                   A                   P
# 20                   P  ...                   P                   P
# 21                   P  ...                   P                   A
# 22                   P  ...                   A                   P
# 23                   P  ...                   P                   P
# 24                   P  ...                   P                   P
# 25                   P  ...                   P                   P
# 26                   A  ...                   A                   A
# 27                   P  ...                   P                   P
# 28                   P  ...                   P                   P
# 29                   P  ...                   P                   A
# 30                   P  ...                   P                   P
# 31                   A  ...                   P                   P
# 32                   P  ...                   P                   P
# 33                   A  ...                   P                   A
# 34                   P  ...                   P                   A
# 35                   P  ...                   A                   P
# 36                   P  ...                   A                   P
# 37                   P  ...                   P                   P
# 38                   P  ...                   P                   P
# 39                   P  ...                   P                   P
#
#    2019-03-15 00:00:00 2019-03-18 00:00:00 2019-03-19 00:00:00 Present Absent
# 0                    P                   P                   P      41      5  \
# 1                    P                   P                   P      40      6
# 2                    A                   P                   P      38      8
# 3                    P                   P                   P      41      5
# 4                    P                   P                   P      39      7
# 5                    P                   P                   A      37      9
# 6                    P                   P                   P      40      6
# 7                    P                   P                   P      42      4
# 8                    A                   P                   P      34     12
# 9                    P                   P                   P      40      6
# 10                   P                   P                   P      40      6
# 11                   P                   P                   P      36     10
# 12                   P                   A                   P      36     10
# 13                   P                   P                   P      42      4
# 14                   A                   P                   P      35     11
# 15                   P                   P                   P      39      7
# 16                   P                   P                   P      41      5
# 17                   A                   P                   P      33     13
# 18                   P                   P                   P      38      8
# 19                   P                   P                   P      37      9
# 20                   P                   P                   P      42      4
# 21                   P                   P                   A      39      7
# 22                   P                   P                   P      36     10
# 23                   P                   P                   P      44      2
# 24                   A                   P                   P      39      7
# 25                   P                   P                   P      38      8
# 26                   P                   P                   P      34     12
# 27                   P                   P                   P      40      6
# 28                   P                   A                   P      40      6
# 29                   P                   P                   P      41      5
# 30                   P                   P                   P      38      8
# 31                   P                   P                   P      42      4
# 32                   P                   P                   P      39      7
# 33                   A                   P                   A      34     12
# 34                   P                   P                   P      41      5
# 35                   P                   P                   P      41      5
# 36                   A                   P                   P      36     10
# 37                   P                   P                   P      42      4
# 38                   A                   P                   P      41      5
# 39                   A                   A                   P      36     10
#
#      %Att UT1 PREL
# 0   89.13  19   31
# 1   86.96  15   64
# 2   82.61  30   64
# 3   89.13  14   26
# 4   84.78  24   45
# 5   80.43  10   32
# 6   86.96  22   46
# 7   91.30  10   33
# 8   73.91  29   56
# 9   86.96  26   41
# 10  86.96  17   56
# 11  78.26  13   40
# 12  78.26  30   31
# 13  91.30  10   35
# 14  76.09  17   43
# 15  84.78  15   49
# 16  89.13  29   30
# 17  71.74  18   60
# 18  82.61  16   64
# 19  80.43  17   28
# 20  91.30  26   33
# 21  84.78  25   40
# 22  78.26  20   35
# 23  95.65  25   55
# 24  84.78  26   57
# 25  82.61  21   56
# 26  73.91  20   29
# 27  86.96  27   65
# 28  86.96  17   32
# 29  89.13  15   57
# 30  82.61  16   30
# 31  91.30  27   47
# 32  84.78  24   44
# 33  73.91  23   51
# 34  89.13  26   54
# 35  89.13  13   29
# 36  78.26  28   26
# 37  91.30  22   59
# 38  89.13  28   64
# 39  78.26  17   45
#
# [40 rows x 53 columns]

# %% [markdown]
# **FIRST MONTHLY ATTENDANCE**

# %%
first_month_att = pd.concat([df, te_students_attendance31(40, '2018-12-24', '2019-01-24')], axis = 1)
first_month_att.to_csv("First_Month_Att.csv")

# %%
first_month_att.head()
# Out:
#    ROLL NO         NAME OF STUDENTS 2018-12-24 00:00:00 2018-12-27 00:00:00
# 0        1  Nangare Abhishek Tanaji                   A                   P  \
# 1        2  Mahajan Aditya Rajendra                   P                   P
# 2        3  Morade Ajinkya Rajendra                   P                   P
# 3        4  Saudagar Avinash Dagadu                   P                   P
# 4        5    Patil Dhananjay Sunil                   A                   P
#
#   2018-12-28 00:00:00 2018-12-31 00:00:00 2019-01-03 00:00:00
# 0                   P                   P                   P  \
# 1                   A                   P                   A
# 2                   A                   P                   P
# 3                   P                   P                   P
# 4                   P                   P                   P
#
#   2019-01-04 00:00:00 2019-01-07 00:00:00 2019-01-08 00:00:00  ...
# 0                   P                   P                   P  ...  \
# 1                   P                   P                   A  ...
# 2                   A                   P                   P  ...
# 3                   P                   P                   P  ...
# 4                   P                   P                   P  ...
#
#   2019-01-15 00:00:00 2019-01-17 00:00:00 2019-01-18 00:00:00
# 0                   P                   A                   P  \
# 1                   P                   P                   P
# 2                   P                   P                   P
# 3                   P                   P                   P
# 4                   P                   P                   P
#
#   2019-01-22 00:00:00 2019-01-24 00:00:00 Present Absent    %Att  UT1  PREL
# 0                   P                   P      13      3   81.25   13    33
# 1                   P                   P      12      4   75.00   23    59
# 2                   P                   P      14      2   87.50   23    51
# 3                   P                   P      16      0  100.00   25    46
# 4                   P                   P      15      1   93.75   13    57
#
# [5 rows x 23 columns]

# %% [markdown]
# **SECOND MONTH THEORY ATTENDANCE**

# %%
second_month_att = pd.concat([df, te_students_attendance31(40, '2019-01-25', '2019-02-25')], axis = 1)
second_month_att.to_csv("Second_Month_Att.csv")

# %%
second_month_att.head()
# Out:
#    ROLL NO         NAME OF STUDENTS 2019-01-25 00:00:00 2019-01-28 00:00:00
# 0        1  Nangare Abhishek Tanaji                   P                   P  \
# 1        2  Mahajan Aditya Rajendra                   P                   P
# 2        3  Morade Ajinkya Rajendra                   P                   P
# 3        4  Saudagar Avinash Dagadu                   P                   P
# 4        5    Patil Dhananjay Sunil                   A                   P
#
#   2019-01-29 00:00:00 2019-01-31 00:00:00 2019-02-01 00:00:00
# 0                   A                   P                   P  \
# 1                   P                   P                   P
# 2                   P                   P                   P
# 3                   P                   P                   A
# 4                   P                   P                   A
#
#   2019-02-04 00:00:00 2019-02-05 00:00:00 2019-02-07 00:00:00  ...
# 0                   P                   P                   P  ...  \
# 1                   P                   P                   P  ...
# 2                   P                   P                   P  ...
# 3                   P                   P                   P  ...
# 4                   P                   A                   A  ...
#
#   2019-02-15 00:00:00 2019-02-19 00:00:00 2019-02-21 00:00:00
# 0                   P                   P                   P  \
# 1                   P                   P                   P
# 2                   P                   P                   P
# 3                   P                   A                   A
# 4                   P                   A                   P
#
#   2019-02-22 00:00:00 2019-02-25 00:00:00 Present Absent   %Att UT1  PREL
# 0                   P                   P      15      2  88.24  29    50
# 1                   A                   P      15      2  88.24  25    61
# 2                   P                   A      15      2  88.24  13    44
# 3                   A                   A      11      6  64.71  15    50
# 4                   P                   P      12      5  70.59  17    52
#
# [5 rows x 24 columns]
