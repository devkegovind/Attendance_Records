# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("D:\Downloads\TE-3_18_19.xlsx")
df
# Out:
#     ROLL NO                 NAME OF STUDENTS
# 0         1          NANGARE ABHISHEK TANAJI
# 1         2          MAHAJAN ADITYA RAJENDRA
# 2         3          MORADE AJINKYA RAJENDRA
# 3         4          SAUDAGAR AVINASH DAGADU
# 4         5            PATIL DHANANJAY SUNIL
# 5         6              ADHAV SAYALI SANJAY
# 6         7             SHINDE NIKHIL SHARAD
# 7         8           SHARMA NISHANK SANTOSH
# 8         9        GAJAKOSH NITESH TULSHIRAM
# 9        10               KOKARE OMKAR ASHOK
# 10       11            YADAV OMKAR BABASAHEB
# 11       12  KULKARNI PRATHAMESH BHALCHANDRA
# 12       13          PATIL PRITESH PRABHAKAR
# 13       14              SHETE SAIRAJ SHARAD
# 14       15          PANASKAR SANDESH SURESH
# 15       16         SHINDE SAURABH BADASHAHA
# 16       17    ABHISHEK SHRIKRUSHNA MADANKAR
# 17       18             MAGAR SHUBHAM DEEPAK
# 18       19            PATIL SHUBHAM SHIVAJI
# 19       20           DHUMAL SIDDHESH DHUMAL
# 20       21            WADKAR SMITHIL MARUTI
# 21       22             GAIKWAD SURAJ BHARAT
# 22       23        BASVEKAR MUKESH BADRINATH
# 23       24         SHUBHAM SHAILENDRA BOLLA
# 24       25            DESHMANE ANIKET ASHOK
# 25       26             DHAVALE SEJAL ANKUSH
# 26       27              GAIKWAD ANIKET RAJU
# 27       28                HARIP AMOGH SUHAS
# 28       29      SARVADE ABHIJEET SHATRUGHNA
# 29       30            JAISWAL SHUBHAM VIJAY
# 30       31             KAKADE DIVYA VISHWAS
# 31       32             KARAD BALAJI SITARAM
# 32       33           LOHAR SAMIKSHA SANTOSH
# 33       34        CHOUDHARY MAMATA SHIVSGAR
# 34       35             SHIVADE DIPAK CHHOTU
# 35       36          WAGHMARE PRAJWAL KISHOR
# 36       37           MULGE MAHADEV CHENNAPA
# 37       38           JAGADALE AKSHAY SANJAY
# 38       39             SARPE MUKESH PRADEEP
# 39       40         DHERE BHOOSHAN PAMESHWAR

# %%
df['NAME OF STUDENTS'] = [i.title() for i in df['NAME OF STUDENTS']]

# %%
df.head()
# Out:
#    ROLL NO         NAME OF STUDENTS
# 0        1  Nangare Abhishek Tanaji
# 1        2  Mahajan Aditya Rajendra
# 2        3  Morade Ajinkya Rajendra
# 3        4  Saudagar Avinash Dagadu
# 4        5    Patil Dhananjay Sunil

# %%
df.to_csv("roll_call.csv")

# %%
df.shape
# Out:
# (40, 2)

# %% [markdown]
# **SEMESTER THEORY ATTENDANCE**

# %%
import random
import pandas as pd
import numpy as np
import datetime
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
import pandas as pd
import holidays

def sem_students_attendance(n, start_year, start_date, end_date):

    students = range(n)
    
    # Set the start and end dates
    start_date = pd.Timestamp(start_date)
    end_date = pd.Timestamp(end_date)

    # Get the Indian holidays for 2021
    indian_holidays = holidays.IND(years=[start_year, start_year+1])

    custom_business_day = CustomBusinessDay(weekmask='Mon Tue Thu Fri', holidays=indian_holidays)

    # Generate a range of dates between the start and end dates
    date_range = pd.date_range(start=start_date, end=end_date, freq=custom_business_day).strftime('%Y-%m-%d')
    


    attendance_records1 = {}
    
    for student in students:
        attendance_records1[student] = []
        
        for day in date_range:
            attendance_records1[student].append('P' if random.random() < 0.85 else 'A')
                
    df = pd.DataFrame.from_dict(attendance_records1, orient='index', columns=date_range)
    df['Present'] = df.apply(lambda x: x[x == 'P'].count(), axis=1)
    df['Absent'] = df.apply(lambda x: x[x == 'A'].count(), axis=1)
    df['%Att'] = round(df['Present'] / len(date_range) * 100)
     
    return df

# %%
d1 = pd.concat([df, sem_students_attendance(40, 2018,'2018-12-24', '2019-03-19')], axis = 1)
d1 = d1.set_index("ROLL NO")
d1.to_excel("D:\\Downloads\\New folder\\2018-19\\SEM_II\\SEM_ATT.xlsx")
d1.to_csv("SEM_ATT.csv")

# %%
import random
import pandas as pd
import numpy as np
import datetime
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
import pandas as pd
import holidays

def sem_students_attendance(n, start_year, start_date, end_date):

    students = range(n)
    
    # Set the start and end dates
    start_date = pd.Timestamp(start_date)
    end_date = pd.Timestamp(end_date)

    # Get the Indian holidays for 2021
    indian_holidays = holidays.IND(years=[start_year, start_year+1])

    custom_business_day = CustomBusinessDay(weekmask='Mon Tue Thu Fri', holidays=indian_holidays)

    # Generate a range of dates between the start and end dates
    date_range = pd.date_range(start=start_date, end=end_date, freq=custom_business_day).strftime('%Y-%m-%d')
    


    attendance_records1 = {}
    
    for student in students:
        attendance_records1[student] = []
        
        for day in date_range:
            attendance_records1[student].append('P' if random.random() < 0.85 else 'A')
                
    df = pd.DataFrame.from_dict(attendance_records1, orient='index', columns=date_range)
    df['Present'] = df.apply(lambda x: x[x == 'P'].count(), axis=1)
    df['Absent'] = df.apply(lambda x: x[x == 'A'].count(), axis=1)
    df['%SUB'] = round(df['Present'] / len(date_range) * 100)
    for i in range(1, 5):
        df[f'%SUB{i+1}'] = np.random.choice(df['%SUB'], size=n)

    df['%AVG'] = df.loc[:, '%SUB':'%SUB5'].mean(axis=1)
     
    return df

# %%
d11 = pd.concat([df, sem_students_attendance(40, 2018,'2018-12-24', '2019-03-19')], axis = 1)
d11 = d11.set_index("ROLL NO")
d11.to_excel("D:\\Downloads\\New folder\\2018-19\\SEM_II\\SEM_ATT11.xlsx")
d11.to_csv("SEM_ATT11.csv")

# %% [markdown]
# **FIRST MONTHLY ATTENDANCE**

# %%
d2 = pd.concat([df, sem_students_attendance(40, 2018,'2018-12-24', '2019-01-24')], axis = 1)
d2 = d2.set_index("ROLL NO")
d2.to_excel("D:\\Downloads\\New folder\\2018-19\\SEM_II\\FIRST_MONTH_ATT.xlsx")
d2.to_csv("FIRST_MONTH_ATT.csv")

# %%
import random
import pandas as pd
import numpy as np
import datetime
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
import pandas as pd
import holidays

def first_month_attendance(n, start_year, start_date, end_date):

    students = range(n)
    
    # Set the start and end dates
    start_date = pd.Timestamp(start_date)
    end_date = pd.Timestamp(end_date)

    # Get the Indian holidays for 2021
    indian_holidays = holidays.IND(years=[start_year, start_year+1])

    custom_business_day = CustomBusinessDay(weekmask='Mon Tue Thu Fri', holidays=indian_holidays)

    # Generate a range of dates between the start and end dates
    date_range = pd.date_range(start=start_date, end=end_date, freq=custom_business_day).strftime('%Y-%m-%d')
    


    attendance_records1 = {}
    
    for student in students:
        attendance_records1[student] = []
        
        for day in date_range:
            attendance_records1[student].append('P' if random.random() < 0.75 else 'A')
                
    df = pd.DataFrame.from_dict(attendance_records1, orient='index', columns=date_range)
    df['Present'] = df.apply(lambda x: x[x == 'P'].count(), axis=1)
    df['Absent'] = df.apply(lambda x: x[x == 'A'].count(), axis=1)
    df['%SUB'] = round(df['Present'] / len(date_range) * 100)
    for i in range(1, 5):
        df[f'%SUB{i+1}'] = np.random.choice(df['%SUB'], size=n)

    df['%AVG'] = df.loc[:, '%SUB':'%SUB5'].mean(axis=1)
     
    return df

# %%
d22 = pd.concat([df, first_month_attendance(40, 2018,'2018-12-24', '2019-01-24')], axis = 1)
d22 = d22.set_index("ROLL NO")
d22.to_excel("D:\\Downloads\\New folder\\2018-19\\SEM_II\\FIRST_MONTH_ATT22.xlsx")
d22.to_csv("FIRST_MONTH_ATT22.csv")

# %% [markdown]
# **SECOND MONTH THEORY ATTENDANCE**

# %%
d3 = pd.concat([df, sem_students_attendance(40, 2018,'2019-01-25', '2019-02-25')], axis = 1)
d3 = d3.set_index("ROLL NO")
d3.to_excel("D:\\Downloads\\New folder\\2018-19\\SEM_II\\SECOND_MONTH_ATT.xlsx")
d3.to_csv("SECOND_MONTH_ATT.csv")

# %%
import random
import pandas as pd
import numpy as np
import datetime
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
import pandas as pd
import holidays

def second_month_attendance(n, start_year, start_date, end_date):

    students = range(n)
    
    # Set the start and end dates
    start_date = pd.Timestamp(start_date)
    end_date = pd.Timestamp(end_date)

    # Get the Indian holidays for 2021
    indian_holidays = holidays.IND(years=[start_year, start_year+0])

    custom_business_day = CustomBusinessDay(weekmask='Mon Tue Thu Fri', holidays=indian_holidays)

    # Generate a range of dates between the start and end dates
    date_range = pd.date_range(start=start_date, end=end_date, freq=custom_business_day).strftime('%Y-%m-%d')
    


    attendance_records1 = {}
    
    for student in students:
        attendance_records1[student] = []
        
        for day in date_range:
            attendance_records1[student].append('P' if random.random() < 0.80 else 'A')
                
    df = pd.DataFrame.from_dict(attendance_records1, orient='index', columns=date_range)
    df['Present'] = df.apply(lambda x: x[x == 'P'].count(), axis=1)
    df['Absent'] = df.apply(lambda x: x[x == 'A'].count(), axis=1)
    df['%SUB'] = round(df['Present'] / len(date_range) * 100)
    for i in range(1, 5):
        df[f'%SUB{i+1}'] = np.random.choice(df['%SUB'], size=n)

    df['%AVG'] = df.loc[:, '%SUB':'%SUB5'].mean(axis=1)
     
    return df

# %%
d33 = pd.concat([df, second_month_attendance(40, 2018,'2019-01-25', '2019-02-25')], axis = 1)
d33 = d33.set_index("ROLL NO")
d33.to_excel("D:\\Downloads\\New folder\\2018-19\\SEM_II\\SECOND_MONTH_ATT33.xlsx")
d33.to_csv("SECOND_MONTH_ATT33.csv")
