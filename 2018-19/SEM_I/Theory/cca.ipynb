# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("D:\Downloads\Roll Call SE, TE _ BE Mech AY 2018-19.xlsx")
df
# Out:
#     ROLL NO                NAME OF STUDENTS
# 0         1            ADALINGE SAGAR BANDU
# 1         2            ANANDE PRITHVI ANANT
# 2         3          AWARI PRATIK BALASAHEB
# 3         4          BAKAL GAURI KRUSHNARAO
# 4         5             BANKAR VISHAL UTTAM
# 5         6             BHOSALE OMKAR VIKAS
# 6         7           CHINCHOLE SHITAL NANA
# 7         8          DEVALE SHAMRAO BABURAO
# 8         9    DHAYARKAR NIKHIL CHANDRABHAN
# 9        10        GHADAGE AISHWARYA MANAJI
# 10       11          GONDKAR SHUBHAM ARVIND
# 11       12             GUND AJIT BHAUSAHEB
# 12       13            JADHAV MAYANK PRAVIN
# 13       14       JADHAV PRIYANKA PANDURANG
# 14       15         JALKUMARBACHUBHAI VASHI
# 15       16         KHAIRNAR PRASAD PRADHAN
# 16       17  KHAN MEHANDI HASAN HAFEEZ KHAN
# 17       18               KOLSE SAHIL ASHOK
# 18       19        LOKHANDE NILESH MAHENDRA
# 19       20             MANKE UJJWAL RAJESH
# 20       21              MALI PAWAN SHRIRAM
# 21       22      MADAKE RAMPRASAD BALASAHEB
# 22       23               MOGHE AMEYA SUNIL
# 23       24             NADKARNI MANGESH NA
# 24       25           OMBASE ANIKET AVINASH
# 25       26        PISAL SHUBHAM SHASHIKANT
# 26       27          PATIL MANISH NADKISHOR
# 27       28            RASAL SOURABH SANJAY
# 28       29    SHELGAONKAR VIRAJ VIJAYKUMAR
# 29       30           SHINDE SAGAR RAVINDRA
# 30       31           SHEDAGE AVADHUT VIJAY
# 31       32        SOMWANSHI SOURABH SANJAY
# 32       33        SONAWANE SHIVAM MAHENDRA
# 33       34       SOMVANSHI SWAPNIL BABURAO
# 34       35              TODKAR SAGAR VIJAY
# 35       36      WAGASKAR SUYOG CHANDRAKANT
# 36       37           WAGH MANGESH KAMLAKAR
# 37       38              MANE KIRAN PRALHAD
# 38       39      KAMBLE RUSHIKESH KHANDERAO
# 39       40       JADHAV ASHWAMEDH YALLAPPA
# 40       41           GAWHANDE VIVEK SANJAY
# 41       42            DHUMAL ADITYA SANJAY
# 42       43            BAKSHE GAVRAV DEELIP
# 43       44              RATHOD VIVEK VILAS
# 44       45           BHAT PRACHI BALASAHEB
# 45       46      NARKHEDE DIMPAL SUNIL (PA)
# 46       47               PATEL JAYESH HARI
# 47       48          PAWAR SAURABH SHRIKANT
# 48       49           ADHAT SAURABH KAILASH
# 49       50             SHAH GAURISH MILIND
# 50       51         CHAUDHARI ANURAG SANDIP
# 51       52          MOTIWALE SUMIT SOMNATH
# 52       53       HASEGAONKAR ATHARV RAMESH
# 53       54         KHANDEKAR AKSHAY VIDISH

# %%
df['NAME OF STUDENTS'] = [i.title() for i in df['NAME OF STUDENTS']]

# %%
df.head()
# Out:
#    ROLL NO        NAME OF STUDENTS
# 0        1    Adalinge Sagar Bandu
# 1        2    Anande Prithvi Anant
# 2        3  Awari Pratik Balasaheb
# 3        4  Bakal Gauri Krushnarao
# 4        5     Bankar Vishal Uttam

# %%
df.shape
# Out:
# (54, 2)

# %%
df.to_csv("roll_call.csv")

# %% [markdown]
# **SEMESTER THEORY ATTENDANCE**

# %%
import random
import pandas as pd
import numpy as np
import datetime
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

def te_students_attendance41(n, start_date, end_date):
    
    students = range(n)
    
    cal = USFederalHolidayCalendar()
    holidays = cal.holidays(start=start_date, end=end_date)
    
    custom_business_day = CustomBusinessDay(weekmask='Tue Thu Fri', holidays=holidays)

    date_range = pd.date_range(start=start_date, end=end_date, freq=custom_business_day)
    
    attendance_records1 = {}
    
    for student in students:
        attendance_records1[student] = []
        
        for day in date_range:
            attendance_records1[student].append('P' if random.random() < 0.85 else 'A')
                
    df = pd.DataFrame.from_dict(attendance_records1, orient='index', columns=date_range)
    df['Present'] = df.apply(lambda x: x[x == 'P'].count(), axis=1)
    df['Absent'] = df.apply(lambda x: x[x == 'A'].count(), axis=1)
    df['%Att'] = round(df['Present'] / len(date_range) * 100,2)
    df['UT1'] = [random.randint(10,30) for i in range(0,n)]
    df['PREL'] = [random.randint(26, 65) for i in range(0, n)]
     
    return df

# %%
sem_att = pd.concat([df, te_students_attendance41(54, '2018-06-18', '2018-10-05')], axis = 1)
sem_att.to_csv("sem_att.csv")

# %% [markdown]
# **FIRST MONTHLY ATTENDANCE**

# %%
first_month_att = pd.concat([df, te_students_attendance41(54, '2018-06-18', '2018-07-18')], axis = 1)
first_month_att.to_csv("First_Month_Att.csv")

# %%
first_month_att
# Out:
#     ROLL NO                NAME OF STUDENTS 2018-06-19 00:00:00
# 0         1            Adalinge Sagar Bandu                   A  \
# 1         2            Anande Prithvi Anant                   P
# 2         3          Awari Pratik Balasaheb                   P
# 3         4          Bakal Gauri Krushnarao                   A
# 4         5             Bankar Vishal Uttam                   P
# 5         6             Bhosale Omkar Vikas                   P
# 6         7           Chinchole Shital Nana                   P
# 7         8          Devale Shamrao Baburao                   P
# 8         9    Dhayarkar Nikhil Chandrabhan                   P
# 9        10        Ghadage Aishwarya Manaji                   P
# 10       11          Gondkar Shubham Arvind                   A
# 11       12             Gund Ajit Bhausaheb                   P
# 12       13            Jadhav Mayank Pravin                   P
# 13       14       Jadhav Priyanka Pandurang                   P
# 14       15         Jalkumarbachubhai Vashi                   P
# 15       16         Khairnar Prasad Pradhan                   P
# 16       17  Khan Mehandi Hasan Hafeez Khan                   P
# 17       18               Kolse Sahil Ashok                   P
# 18       19        Lokhande Nilesh Mahendra                   P
# 19       20             Manke Ujjwal Rajesh                   A
# 20       21              Mali Pawan Shriram                   P
# 21       22      Madake Ramprasad Balasaheb                   P
# 22       23               Moghe Ameya Sunil                   P
# 23       24             Nadkarni Mangesh Na                   P
# 24       25           Ombase Aniket Avinash                   P
# 25       26        Pisal Shubham Shashikant                   P
# 26       27          Patil Manish Nadkishor                   A
# 27       28            Rasal Sourabh Sanjay                   P
# 28       29    Shelgaonkar Viraj Vijaykumar                   P
# 29       30           Shinde Sagar Ravindra                   P
# 30       31           Shedage Avadhut Vijay                   A
# 31       32        Somwanshi Sourabh Sanjay                   P
# 32       33        Sonawane Shivam Mahendra                   P
# 33       34       Somvanshi Swapnil Baburao                   P
# 34       35              Todkar Sagar Vijay                   P
# 35       36      Wagaskar Suyog Chandrakant                   A
# 36       37           Wagh Mangesh Kamlakar                   P
# 37       38              Mane Kiran Pralhad                   A
# 38       39      Kamble Rushikesh Khanderao                   P
# 39       40       Jadhav Ashwamedh Yallappa                   P
# 40       41           Gawhande Vivek Sanjay                   P
# 41       42            Dhumal Aditya Sanjay                   A
# 42       43            Bakshe Gavrav Deelip                   P
# 43       44              Rathod Vivek Vilas                   P
# 44       45           Bhat Prachi Balasaheb                   P
# 45       46      Narkhede Dimpal Sunil (Pa)                   P
# 46       47               Patel Jayesh Hari                   P
# 47       48          Pawar Saurabh Shrikant                   P
# 48       49           Adhat Saurabh Kailash                   P
# 49       50             Shah Gaurish Milind                   P
# 50       51         Chaudhari Anurag Sandip                   P
# 51       52          Motiwale Sumit Somnath                   P
# 52       53       Hasegaonkar Atharv Ramesh                   P
# 53       54         Khandekar Akshay Vidish                   P
#
#    2018-06-21 00:00:00 2018-06-22 00:00:00 2018-06-26 00:00:00
# 0                    P                   P                   P  \
# 1                    P                   P                   P
# 2                    P                   A                   A
# 3                    P                   P                   A
# 4                    P                   P                   P
# 5                    P                   P                   P
# 6                    P                   P                   P
# 7                    P                   P                   P
# 8                    P                   P                   P
# 9                    P                   P                   P
# 10                   A                   P                   P
# 11                   P                   A                   P
# 12                   P                   P                   P
# 13                   P                   P                   P
# 14                   P                   P                   P
# 15                   P                   P                   P
# 16                   P                   P                   P
# 17                   P                   P                   P
# 18                   P                   P                   P
# 19                   P                   P                   A
# 20                   P                   P                   P
# 21                   P                   P                   P
# 22                   P                   P                   P
# 23                   P                   A                   A
# 24                   P                   P                   P
# 25                   P                   A                   P
# 26                   P                   P                   P
# 27                   P                   P                   P
# 28                   P                   P                   P
# 29                   P                   P                   A
# 30                   A                   P                   A
# 31                   P                   A                   P
# 32                   P                   P                   P
# 33                   P                   P                   P
# 34                   P                   P                   P
# 35                   P                   P                   P
# 36                   P                   P                   P
# 37                   P                   P                   P
# 38                   A                   P                   P
# 39                   A                   A                   P
# 40                   P                   P                   P
# 41                   P                   P                   P
# 42                   P                   P                   P
# 43                   P                   P                   P
# 44                   P                   P                   P
# 45                   P                   P                   P
# 46                   P                   P                   P
# 47                   P                   P                   P
# 48                   P                   A                   P
# 49                   P                   P                   P
# 50                   P                   P                   P
# 51                   A                   A                   P
# 52                   P                   P                   P
# 53                   P                   P                   P
#
#    2018-06-28 00:00:00 2018-06-29 00:00:00 2018-07-03 00:00:00
# 0                    P                   P                   P  \
# 1                    P                   P                   P
# 2                    P                   P                   P
# 3                    P                   A                   P
# 4                    P                   P                   P
# 5                    P                   P                   P
# 6                    P                   P                   P
# 7                    P                   P                   P
# 8                    P                   P                   P
# 9                    P                   P                   P
# 10                   A                   P                   P
# 11                   P                   P                   P
# 12                   P                   P                   P
# 13                   P                   P                   A
# 14                   P                   A                   A
# 15                   P                   P                   P
# 16                   P                   P                   P
# 17                   P                   P                   P
# 18                   P                   P                   P
# 19                   P                   A                   P
# 20                   P                   P                   P
# 21                   P                   A                   P
# 22                   P                   P                   A
# 23                   P                   P                   P
# 24                   P                   P                   A
# 25                   P                   A                   P
# 26                   P                   P                   P
# 27                   P                   P                   P
# 28                   P                   P                   P
# 29                   P                   P                   P
# 30                   P                   P                   P
# 31                   P                   P                   P
# 32                   P                   P                   A
# 33                   P                   P                   P
# 34                   P                   P                   A
# 35                   P                   P                   P
# 36                   P                   P                   P
# 37                   P                   P                   A
# 38                   P                   P                   P
# 39                   A                   P                   P
# 40                   A                   P                   P
# 41                   P                   P                   P
# 42                   P                   P                   P
# 43                   P                   P                   P
# 44                   P                   P                   P
# 45                   P                   A                   P
# 46                   P                   P                   A
# 47                   P                   P                   P
# 48                   A                   P                   P
# 49                   P                   P                   P
# 50                   P                   P                   A
# 51                   P                   P                   P
# 52                   P                   P                   P
# 53                   P                   P                   P
#
#    2018-07-05 00:00:00 2018-07-06 00:00:00 2018-07-10 00:00:00
# 0                    A                   P                   P  \
# 1                    P                   P                   P
# 2                    P                   P                   P
# 3                    P                   P                   A
# 4                    P                   A                   P
# 5                    A                   P                   P
# 6                    P                   A                   P
# 7                    P                   A                   A
# 8                    A                   P                   P
# 9                    P                   P                   A
# 10                   P                   P                   P
# 11                   A                   P                   P
# 12                   P                   P                   A
# 13                   P                   P                   P
# 14                   P                   P                   A
# 15                   P                   P                   A
# 16                   P                   P                   P
# 17                   A                   P                   P
# 18                   P                   P                   A
# 19                   P                   P                   P
# 20                   P                   P                   P
# 21                   A                   P                   A
# 22                   P                   P                   P
# 23                   P                   P                   P
# 24                   P                   P                   P
# 25                   P                   P                   P
# 26                   P                   P                   P
# 27                   P                   A                   P
# 28                   P                   A                   A
# 29                   P                   P                   A
# 30                   P                   P                   P
# 31                   P                   P                   P
# 32                   P                   P                   P
# 33                   A                   P                   P
# 34                   P                   P                   P
# 35                   P                   P                   P
# 36                   P                   P                   P
# 37                   P                   P                   P
# 38                   P                   P                   P
# 39                   P                   P                   P
# 40                   A                   A                   P
# 41                   A                   A                   P
# 42                   P                   P                   P
# 43                   P                   A                   P
# 44                   P                   P                   P
# 45                   P                   A                   P
# 46                   P                   P                   P
# 47                   P                   P                   P
# 48                   P                   P                   P
# 49                   P                   P                   P
# 50                   P                   P                   P
# 51                   P                   P                   P
# 52                   P                   P                   P
# 53                   P                   P                   P
#
#    2018-07-12 00:00:00 2018-07-13 00:00:00 2018-07-17 00:00:00  Present
# 0                    A                   P                   P       10  \
# 1                    P                   P                   P       13
# 2                    P                   P                   P       11
# 3                    P                   P                   A        8
# 4                    P                   P                   P       12
# 5                    P                   P                   P       12
# 6                    P                   P                   A       11
# 7                    P                   A                   A        9
# 8                    P                   A                   P       11
# 9                    P                   P                   A       11
# 10                   P                   P                   P       10
# 11                   A                   P                   P       10
# 12                   P                   A                   P       11
# 13                   P                   P                   A       11
# 14                   P                   P                   P       10
# 15                   P                   P                   P       12
# 16                   P                   P                   P       13
# 17                   P                   A                   A       10
# 18                   P                   P                   P       12
# 19                   P                   P                   P       10
# 20                   A                   P                   P       12
# 21                   P                   P                   P       10
# 22                   P                   P                   P       12
# 23                   A                   P                   P       10
# 24                   P                   P                   A       11
# 25                   A                   P                   A        9
# 26                   P                   P                   P       12
# 27                   P                   A                   P       11
# 28                   P                   P                   P       11
# 29                   P                   P                   P       11
# 30                   P                   P                   P       10
# 31                   A                   P                   P       11
# 32                   P                   A                   P       11
# 33                   P                   P                   P       12
# 34                   P                   P                   P       12
# 35                   P                   P                   P       12
# 36                   P                   P                   P       13
# 37                   P                   P                   P       11
# 38                   P                   P                   P       12
# 39                   A                   P                   A        8
# 40                   A                   P                   P        9
# 41                   A                   A                   A        7
# 42                   P                   P                   P       13
# 43                   P                   P                   P       12
# 44                   A                   P                   P       12
# 45                   P                   P                   P       11
# 46                   A                   P                   P       11
# 47                   P                   A                   A       11
# 48                   A                   A                   A        8
# 49                   P                   A                   P       12
# 50                   P                   P                   P       12
# 51                   P                   P                   P       11
# 52                   P                   P                   P       13
# 53                   P                   P                   P       13
#
#     Absent    %Att  UT1  PREL
# 0        3   76.92   29    36
# 1        0  100.00   10    54
# 2        2   84.62   14    47
# 3        5   61.54   21    63
# 4        1   92.31   19    35
# 5        1   92.31   12    33
# 6        2   84.62   10    44
# 7        4   69.23   28    58
# 8        2   84.62   14    51
# 9        2   84.62   18    35
# 10       3   76.92   27    28
# 11       3   76.92   17    44
# 12       2   84.62   28    35
# 13       2   84.62   17    47
# 14       3   76.92   25    51
# 15       1   92.31   19    43
# 16       0  100.00   25    47
# 17       3   76.92   19    43
# 18       1   92.31   10    45
# 19       3   76.92   12    58
# 20       1   92.31   15    63
# 21       3   76.92   18    46
# 22       1   92.31   27    54
# 23       3   76.92   10    27
# 24       2   84.62   25    27
# 25       4   69.23   19    35
# 26       1   92.31   23    55
# 27       2   84.62   14    57
# 28       2   84.62   29    33
# 29       2   84.62   10    56
# 30       3   76.92   25    44
# 31       2   84.62   23    61
# 32       2   84.62   11    52
# 33       1   92.31   27    65
# 34       1   92.31   19    27
# 35       1   92.31   19    40
# 36       0  100.00   14    29
# 37       2   84.62   21    26
# 38       1   92.31   15    28
# 39       5   61.54   24    51
# 40       4   69.23   21    43
# 41       6   53.85   15    60
# 42       0  100.00   19    46
# 43       1   92.31   26    33
# 44       1   92.31   30    38
# 45       2   84.62   26    43
# 46       2   84.62   19    60
# 47       2   84.62   30    30
# 48       5   61.54   30    55
# 49       1   92.31   15    33
# 50       1   92.31   24    48
# 51       2   84.62   19    47
# 52       0  100.00   15    47
# 53       0  100.00   12    54

# %% [markdown]
# **SECOND MONTH THEORY ATTENDANCE**

# %%
second_month_att = pd.concat([df, te_students_attendance41(54, '2018-07-19', '2018-08-19')], axis = 1)
second_month_att.to_csv("Second_Month_Att.csv")

# %%
second_month_att
# Out:
#     ROLL NO                NAME OF STUDENTS 2018-07-19 00:00:00
# 0         1            Adalinge Sagar Bandu                   P  \
# 1         2            Anande Prithvi Anant                   A
# 2         3          Awari Pratik Balasaheb                   P
# 3         4          Bakal Gauri Krushnarao                   P
# 4         5             Bankar Vishal Uttam                   A
# 5         6             Bhosale Omkar Vikas                   P
# 6         7           Chinchole Shital Nana                   P
# 7         8          Devale Shamrao Baburao                   P
# 8         9    Dhayarkar Nikhil Chandrabhan                   P
# 9        10        Ghadage Aishwarya Manaji                   P
# 10       11          Gondkar Shubham Arvind                   P
# 11       12             Gund Ajit Bhausaheb                   P
# 12       13            Jadhav Mayank Pravin                   P
# 13       14       Jadhav Priyanka Pandurang                   P
# 14       15         Jalkumarbachubhai Vashi                   P
# 15       16         Khairnar Prasad Pradhan                   P
# 16       17  Khan Mehandi Hasan Hafeez Khan                   P
# 17       18               Kolse Sahil Ashok                   P
# 18       19        Lokhande Nilesh Mahendra                   P
# 19       20             Manke Ujjwal Rajesh                   P
# 20       21              Mali Pawan Shriram                   A
# 21       22      Madake Ramprasad Balasaheb                   P
# 22       23               Moghe Ameya Sunil                   P
# 23       24             Nadkarni Mangesh Na                   P
# 24       25           Ombase Aniket Avinash                   P
# 25       26        Pisal Shubham Shashikant                   A
# 26       27          Patil Manish Nadkishor                   P
# 27       28            Rasal Sourabh Sanjay                   A
# 28       29    Shelgaonkar Viraj Vijaykumar                   P
# 29       30           Shinde Sagar Ravindra                   P
# 30       31           Shedage Avadhut Vijay                   P
# 31       32        Somwanshi Sourabh Sanjay                   P
# 32       33        Sonawane Shivam Mahendra                   A
# 33       34       Somvanshi Swapnil Baburao                   P
# 34       35              Todkar Sagar Vijay                   P
# 35       36      Wagaskar Suyog Chandrakant                   P
# 36       37           Wagh Mangesh Kamlakar                   P
# 37       38              Mane Kiran Pralhad                   A
# 38       39      Kamble Rushikesh Khanderao                   P
# 39       40       Jadhav Ashwamedh Yallappa                   P
# 40       41           Gawhande Vivek Sanjay                   P
# 41       42            Dhumal Aditya Sanjay                   P
# 42       43            Bakshe Gavrav Deelip                   P
# 43       44              Rathod Vivek Vilas                   P
# 44       45           Bhat Prachi Balasaheb                   A
# 45       46      Narkhede Dimpal Sunil (Pa)                   P
# 46       47               Patel Jayesh Hari                   P
# 47       48          Pawar Saurabh Shrikant                   P
# 48       49           Adhat Saurabh Kailash                   P
# 49       50             Shah Gaurish Milind                   P
# 50       51         Chaudhari Anurag Sandip                   P
# 51       52          Motiwale Sumit Somnath                   P
# 52       53       Hasegaonkar Atharv Ramesh                   P
# 53       54         Khandekar Akshay Vidish                   P
#
#    2018-07-20 00:00:00 2018-07-24 00:00:00 2018-07-26 00:00:00
# 0                    P                   P                   A  \
# 1                    P                   P                   P
# 2                    P                   P                   P
# 3                    P                   P                   P
# 4                    P                   P                   P
# 5                    P                   P                   P
# 6                    P                   A                   P
# 7                    P                   P                   P
# 8                    A                   P                   P
# 9                    P                   P                   P
# 10                   P                   P                   P
# 11                   P                   P                   P
# 12                   P                   P                   P
# 13                   A                   P                   P
# 14                   P                   A                   P
# 15                   P                   P                   P
# 16                   A                   P                   P
# 17                   P                   P                   P
# 18                   P                   P                   P
# 19                   P                   P                   P
# 20                   A                   P                   A
# 21                   P                   P                   P
# 22                   P                   A                   P
# 23                   P                   P                   P
# 24                   P                   P                   P
# 25                   A                   P                   P
# 26                   P                   A                   P
# 27                   P                   A                   A
# 28                   P                   A                   P
# 29                   A                   P                   P
# 30                   P                   P                   P
# 31                   A                   P                   P
# 32                   P                   P                   P
# 33                   P                   P                   P
# 34                   A                   P                   P
# 35                   P                   P                   P
# 36                   P                   P                   P
# 37                   P                   P                   P
# 38                   P                   P                   P
# 39                   P                   P                   P
# 40                   P                   P                   P
# 41                   P                   A                   P
# 42                   P                   P                   P
# 43                   P                   P                   P
# 44                   A                   A                   P
# 45                   P                   P                   A
# 46                   P                   P                   P
# 47                   P                   P                   P
# 48                   P                   A                   P
# 49                   P                   P                   P
# 50                   A                   P                   P
# 51                   A                   P                   P
# 52                   P                   P                   P
# 53                   P                   P                   P
#
#    2018-07-27 00:00:00 2018-07-31 00:00:00 2018-08-02 00:00:00
# 0                    P                   P                   P  \
# 1                    P                   P                   P
# 2                    P                   P                   P
# 3                    A                   P                   P
# 4                    P                   P                   P
# 5                    P                   P                   P
# 6                    P                   P                   P
# 7                    P                   P                   P
# 8                    P                   P                   P
# 9                    P                   P                   P
# 10                   P                   P                   P
# 11                   P                   P                   P
# 12                   P                   P                   P
# 13                   P                   P                   P
# 14                   A                   P                   P
# 15                   P                   P                   P
# 16                   P                   P                   P
# 17                   P                   P                   A
# 18                   P                   A                   P
# 19                   P                   P                   P
# 20                   A                   P                   A
# 21                   P                   P                   P
# 22                   A                   P                   A
# 23                   P                   P                   P
# 24                   P                   A                   P
# 25                   P                   A                   P
# 26                   P                   P                   P
# 27                   P                   P                   P
# 28                   P                   P                   P
# 29                   P                   P                   P
# 30                   P                   P                   P
# 31                   P                   P                   P
# 32                   P                   P                   P
# 33                   P                   P                   P
# 34                   P                   P                   P
# 35                   P                   P                   P
# 36                   P                   P                   P
# 37                   P                   P                   P
# 38                   P                   P                   P
# 39                   P                   P                   P
# 40                   P                   P                   P
# 41                   P                   P                   P
# 42                   P                   P                   P
# 43                   P                   P                   P
# 44                   P                   P                   P
# 45                   P                   P                   P
# 46                   P                   P                   A
# 47                   P                   P                   P
# 48                   P                   P                   A
# 49                   A                   P                   A
# 50                   P                   A                   A
# 51                   P                   P                   P
# 52                   P                   A                   A
# 53                   P                   P                   P
#
#    2018-08-03 00:00:00  ... 2018-08-09 00:00:00 2018-08-10 00:00:00
# 0                    P  ...                   P                   A  \
# 1                    P  ...                   P                   P
# 2                    P  ...                   P                   P
# 3                    P  ...                   P                   P
# 4                    P  ...                   P                   P
# 5                    P  ...                   P                   A
# 6                    P  ...                   P                   A
# 7                    P  ...                   P                   P
# 8                    A  ...                   P                   P
# 9                    P  ...                   P                   P
# 10                   P  ...                   P                   P
# 11                   P  ...                   P                   P
# 12                   P  ...                   P                   P
# 13                   P  ...                   P                   P
# 14                   P  ...                   P                   P
# 15                   P  ...                   P                   P
# 16                   P  ...                   P                   P
# 17                   P  ...                   P                   P
# 18                   P  ...                   P                   P
# 19                   P  ...                   A                   P
# 20                   A  ...                   P                   P
# 21                   P  ...                   P                   P
# 22                   P  ...                   P                   P
# 23                   P  ...                   A                   P
# 24                   P  ...                   P                   P
# 25                   P  ...                   P                   P
# 26                   A  ...                   P                   P
# 27                   P  ...                   A                   A
# 28                   A  ...                   P                   P
# 29                   P  ...                   P                   P
# 30                   P  ...                   P                   A
# 31                   P  ...                   A                   P
# 32                   P  ...                   P                   P
# 33                   P  ...                   P                   P
# 34                   P  ...                   P                   P
# 35                   P  ...                   P                   P
# 36                   P  ...                   P                   P
# 37                   P  ...                   P                   P
# 38                   P  ...                   P                   A
# 39                   P  ...                   P                   P
# 40                   P  ...                   P                   P
# 41                   P  ...                   P                   P
# 42                   P  ...                   P                   P
# 43                   P  ...                   P                   P
# 44                   P  ...                   P                   P
# 45                   P  ...                   P                   A
# 46                   P  ...                   P                   P
# 47                   P  ...                   P                   P
# 48                   P  ...                   P                   P
# 49                   P  ...                   A                   P
# 50                   P  ...                   A                   P
# 51                   P  ...                   A                   P
# 52                   P  ...                   P                   P
# 53                   P  ...                   P                   P
#
#    2018-08-14 00:00:00 2018-08-16 00:00:00 2018-08-17 00:00:00 Present
# 0                    P                   P                   P      12  \
# 1                    P                   P                   A      11
# 2                    A                   P                   P      13
# 3                    P                   A                   P      12
# 4                    P                   A                   P      12
# 5                    P                   P                   P      13
# 6                    A                   P                   P      11
# 7                    P                   P                   P      14
# 8                    P                   P                   P      11
# 9                    P                   P                   A      13
# 10                   P                   A                   P      13
# 11                   P                   P                   P      14
# 12                   P                   P                   P      14
# 13                   P                   P                   P      13
# 14                   A                   P                   P      11
# 15                   P                   P                   P      14
# 16                   P                   P                   P      13
# 17                   P                   P                   P      13
# 18                   A                   P                   P      11
# 19                   P                   P                   P      13
# 20                   P                   A                   P       7
# 21                   P                   A                   P      13
# 22                   P                   P                   A      10
# 23                   P                   P                   P      13
# 24                   P                   P                   P      13
# 25                   P                   P                   P      11
# 26                   P                   P                   P      12
# 27                   A                   P                   P       8
# 28                   P                   P                   P      11
# 29                   P                   P                   P      13
# 30                   P                   P                   P      12
# 31                   P                   A                   A      10
# 32                   P                   A                   P      12
# 33                   P                   P                   P      14
# 34                   P                   P                   P      13
# 35                   P                   P                   P      14
# 36                   P                   P                   P      14
# 37                   P                   P                   P      13
# 38                   P                   P                   P      13
# 39                   P                   P                   P      14
# 40                   P                   P                   P      14
# 41                   P                   P                   A      12
# 42                   P                   P                   A      13
# 43                   P                   P                   P      14
# 44                   P                   A                   P      10
# 45                   P                   P                   A      11
# 46                   P                   P                   P      13
# 47                   P                   P                   P      14
# 48                   A                   P                   A      10
# 49                   P                   A                   P      10
# 50                   P                   P                   P      10
# 51                   P                   A                   P      11
# 52                   P                   P                   P      12
# 53                   P                   P                   P      14
#
#     Absent    %Att  UT1  PREL
# 0        2   85.71   19    50
# 1        3   78.57   17    39
# 2        1   92.86   25    28
# 3        2   85.71   27    51
# 4        2   85.71   13    57
# 5        1   92.86   17    26
# 6        3   78.57   21    57
# 7        0  100.00   10    42
# 8        3   78.57   25    52
# 9        1   92.86   14    37
# 10       1   92.86   11    48
# 11       0  100.00   17    43
# 12       0  100.00   28    65
# 13       1   92.86   20    43
# 14       3   78.57   24    33
# 15       0  100.00   12    39
# 16       1   92.86   19    30
# 17       1   92.86   21    50
# 18       3   78.57   17    44
# 19       1   92.86   29    30
# 20       7   50.00   29    51
# 21       1   92.86   12    57
# 22       4   71.43   22    44
# 23       1   92.86   21    43
# 24       1   92.86   10    54
# 25       3   78.57   25    38
# 26       2   85.71   30    27
# 27       6   57.14   20    45
# 28       3   78.57   30    57
# 29       1   92.86   28    65
# 30       2   85.71   17    40
# 31       4   71.43   24    27
# 32       2   85.71   20    29
# 33       0  100.00   20    28
# 34       1   92.86   28    38
# 35       0  100.00   28    58
# 36       0  100.00   19    59
# 37       1   92.86   20    53
# 38       1   92.86   25    37
# 39       0  100.00   13    26
# 40       0  100.00   30    59
# 41       2   85.71   19    30
# 42       1   92.86   19    61
# 43       0  100.00   29    38
# 44       4   71.43   25    28
# 45       3   78.57   20    47
# 46       1   92.86   29    56
# 47       0  100.00   14    48
# 48       4   71.43   20    27
# 49       4   71.43   22    55
# 50       4   71.43   28    61
# 51       3   78.57   11    47
# 52       2   85.71   21    36
# 53       0  100.00   14    38
#
# [54 rows x 21 columns]
