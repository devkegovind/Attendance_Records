# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("D:\Downloads\Roll Call SE, TE _ BE Mech AY 2017-18.xlsx")

# %%
df
# Out:
#     Roll No.               Name of Student
# 0          1         AIGALIKAR GIRI SUDHIR
# 1          2         APALE SAHIL JAYANTRAO
# 2          3                    ARPIT SHAH
# 3          4         BANDGAR AKSHAY SAMPAT
# 4          5         BHUWAD SANKET SANTOSH
# ..       ...                           ...
# 59        60    SALUNKE SHUBHAM BHASKARRAO
# 60        61  WATPADE SHUBHAM DNYANESHWAR
# 61        62     SWARALI SADASHIV KHADTARE
# 62        63          YADAV DHANESH TANAJI
# 63        64    PATIL PULKESHI BHALCHANDRA
#
# [64 rows x 2 columns]

# %%
df['Name of Student'] = [i.title() for i in df['Name of Student']]

# %%
df.head()
# Out:
#    Roll No.        Name of Student
# 0         1  Aigalikar Giri Sudhir
# 1         2  Apale Sahil Jayantrao
# 2         3             Arpit Shah
# 3         4  Bandgar Akshay Sampat
# 4         5  Bhuwad Sanket Santosh

# %%
#df.to_csv("BE-3.csv")

# %% [markdown]
# **SEMESTER ATTENDANCE**

# %%
import random
import pandas as pd
import numpy as np
import datetime
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
import pandas as pd
import holidays

def sem_students_attendance(n, start_year, start_date, end_date):

    students = range(n)
    
    # Set the start and end dates
    start_date = pd.Timestamp(start_date)
    end_date = pd.Timestamp(end_date)

    # Get the Indian holidays for 2021
    indian_holidays = holidays.IND(years=[start_year, start_year+0])

    custom_business_day = CustomBusinessDay(weekmask='Tue Wed Thu Fri', holidays=indian_holidays)

    # Generate a range of dates between the start and end dates
    date_range = pd.date_range(start=start_date, end=end_date, freq=custom_business_day).strftime('%Y-%m-%d')
    


    attendance_records1 = {}
    
    for student in students:
        attendance_records1[student] = []
        
        for day in date_range:
            attendance_records1[student].append('P' if random.random() < 0.85 else 'A')
                
    df = pd.DataFrame.from_dict(attendance_records1, orient='index', columns=date_range)
    df['Present'] = df.apply(lambda x: x[x == 'P'].count(), axis=1)
    df['Absent'] = df.apply(lambda x: x[x == 'A'].count(), axis=1)
    df['%SUB'] = round(df['Present'] / len(date_range) * 100)
    for i in range(1, 5):
        df[f'%SUB{i+1}'] = np.random.choice(df['%SUB'], size=n)

    df['%AVG'] = df.loc[:, '%SUB':'%SUB5'].mean(axis=1)
     
    return df

# %%
d1 = pd.concat([df, sem_students_attendance(64, 2017, '2017-06-15', '2017-09-29')], axis = 1)
d1 = d1.set_index("Roll No.")
d1.to_excel("D:\\Downloads\\New folder\\2017-18\\SEM_I\\SEM_ATT1.xlsx")
d1.to_csv("SEM_ATT1.csv")

# %%
d1.head()
# Out:
#                 Name of Student 2017-06-15 2017-06-16 2017-06-20 2017-06-21
# Roll No.
# 1         Aigalikar Giri Sudhir          P          P          A          P  \
# 2         Apale Sahil Jayantrao          P          A          P          P
# 3                    Arpit Shah          P          P          P          P
# 4         Bandgar Akshay Sampat          P          A          P          P
# 5         Bhuwad Sanket Santosh          P          P          P          P
#
#          2017-06-22 2017-06-23 2017-06-27 2017-06-28 2017-06-29  ...
# Roll No.                                                         ...
# 1                 P          P          P          P          P  ...  \
# 2                 P          P          P          P          P  ...
# 3                 P          P          P          P          P  ...
# 4                 P          A          P          P          P  ...
# 5                 P          P          P          P          P  ...
#
#          2017-09-28 2017-09-29 Present Absent  %SUB %SUB2 %SUB3 %SUB4 %SUB5
# Roll No.
# 1                 P          P      53      7  88.0  90.0  90.0  83.0  82.0  \
# 2                 P          P      54      6  90.0  90.0  82.0  85.0  82.0
# 3                 P          P      53      7  88.0  83.0  80.0  83.0  85.0
# 4                 P          P      46     14  77.0  80.0  85.0  77.0  82.0
# 5                 P          P      54      6  90.0  85.0  90.0  88.0  82.0
#
#           %AVG
# Roll No.
# 1         86.6
# 2         85.8
# 3         83.8
# 4         80.2
# 5         87.0
#
# [5 rows x 69 columns]

# %% [markdown]
# **First Monthly Attendance**

# %%
import random
import pandas as pd
import numpy as np
import datetime
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
import pandas as pd
import holidays

def first_month_attendance(n, start_year, start_date, end_date):

    students = range(n)
    
    # Set the start and end dates
    start_date = pd.Timestamp(start_date)
    end_date = pd.Timestamp(end_date)

    # Get the Indian holidays for 2021
    indian_holidays = holidays.IND(years=[start_year, start_year+0])

    custom_business_day = CustomBusinessDay(weekmask='Tue Wed Thu Fri', holidays=indian_holidays)

    # Generate a range of dates between the start and end dates
    date_range = pd.date_range(start=start_date, end=end_date, freq=custom_business_day).strftime('%Y-%m-%d')
    


    attendance_records1 = {}
    
    for student in students:
        attendance_records1[student] = []
        
        for day in date_range:
            attendance_records1[student].append('P' if random.random() < 0.75 else 'A')
                
    df = pd.DataFrame.from_dict(attendance_records1, orient='index', columns=date_range)
    df['Present'] = df.apply(lambda x: x[x == 'P'].count(), axis=1)
    df['Absent'] = df.apply(lambda x: x[x == 'A'].count(), axis=1)
    df['%SUB'] = round(df['Present'] / len(date_range) * 100)
    for i in range(1, 5):
        df[f'%SUB{i+1}'] = np.random.choice(df['%SUB'], size=n)

    df['%AVG'] = df.loc[:, '%SUB':'%SUB5'].mean(axis=1)
     
    return df

# %%
d2 = pd.concat([df,first_month_attendance(64, 2017, '2017-06-15', '2017-07-15')], axis =1)
d2 = d2.set_index("Roll No.")
d2.to_excel("D:\\Downloads\\New folder\\2017-18\\SEM_I\\FIRST_ATT1.xlsx")
d2.to_csv("FIRST_MONTH_ATT1.csv")

# %%
d2.head()
# Out:
#                 Name of Student 2017-06-15 2017-06-16 2017-06-20 2017-06-21
# Roll No.
# 1         Aigalikar Giri Sudhir          P          P          P          P  \
# 2         Apale Sahil Jayantrao          P          P          P          A
# 3                    Arpit Shah          A          P          P          P
# 4         Bandgar Akshay Sampat          A          P          P          P
# 5         Bhuwad Sanket Santosh          P          P          A          P
#
#          2017-06-22 2017-06-23 2017-06-27 2017-06-28 2017-06-29  ...
# Roll No.                                                         ...
# 1                 A          P          P          A          P  ...  \
# 2                 P          P          A          P          A  ...
# 3                 A          P          P          P          P  ...
# 4                 A          P          P          P          P  ...
# 5                 P          A          P          P          A  ...
#
#          2017-07-13 2017-07-14 Present Absent  %SUB %SUB2 %SUB3 %SUB4 %SUB5
# Roll No.
# 1                 P          P      13      5  72.0  67.0  67.0  78.0  72.0  \
# 2                 A          P      11      7  61.0  67.0  78.0  72.0  89.0
# 3                 P          A      12      6  67.0  83.0  67.0  67.0  83.0
# 4                 P          P      13      5  72.0  78.0  72.0  83.0  89.0
# 5                 P          A      12      6  67.0  83.0  72.0  61.0  78.0
#
#           %AVG
# Roll No.
# 1         71.2
# 2         73.4
# 3         73.4
# 4         78.8
# 5         72.2
#
# [5 rows x 27 columns]

# %% [markdown]
# **Second Monthly Attendance**

# %%
import random
import pandas as pd
import numpy as np
import datetime
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
import pandas as pd
import holidays

def second_month_attendance(n, start_year, start_date, end_date):

    students = range(n)
    
    # Set the start and end dates
    start_date = pd.Timestamp(start_date)
    end_date = pd.Timestamp(end_date)

    # Get the Indian holidays for 2021
    indian_holidays = holidays.IND(years=[start_year, start_year+0])

    custom_business_day = CustomBusinessDay(weekmask='Tue Wed Thu Fri', holidays=indian_holidays)

    # Generate a range of dates between the start and end dates
    date_range = pd.date_range(start=start_date, end=end_date, freq=custom_business_day).strftime('%Y-%m-%d')
    


    attendance_records1 = {}
    
    for student in students:
        attendance_records1[student] = []
        
        for day in date_range:
            attendance_records1[student].append('P' if random.random() < 0.80 else 'A')
                
    df = pd.DataFrame.from_dict(attendance_records1, orient='index', columns=date_range)
    df['Present'] = df.apply(lambda x: x[x == 'P'].count(), axis=1)
    df['Absent'] = df.apply(lambda x: x[x == 'A'].count(), axis=1)
    df['%SUB'] = round(df['Present'] / len(date_range) * 100)
    for i in range(1, 5):
        df[f'%SUB{i+1}'] = np.random.choice(df['%SUB'], size=n)

    df['%AVG'] = df.loc[:, '%SUB':'%SUB5'].mean(axis=1)
     
    return df

# %%
d3 = pd.concat([df,second_month_attendance(64, 2017,'2017-07-16', '2017-08-16')], axis =1)
d3 = d3.set_index("Roll No.")
d3.to_excel("D:\\Downloads\\New folder\\2017-18\\SEM_I\\SECOND_ATT1.xlsx")
d3.to_csv("SECOND_MONTH_ATT1.csv")

# %%
d3.head()
# Out:
#                 Name of Student 2017-07-18 2017-07-19 2017-07-20 2017-07-21
# Roll No.
# 1         Aigalikar Giri Sudhir          P          P          P          P  \
# 2         Apale Sahil Jayantrao          P          P          P          P
# 3                    Arpit Shah          P          P          A          P
# 4         Bandgar Akshay Sampat          A          P          P          P
# 5         Bhuwad Sanket Santosh          P          P          P          A
#
#          2017-07-25 2017-07-26 2017-07-27 2017-07-28 2017-08-01  ...
# Roll No.                                                         ...
# 1                 P          A          P          P          P  ...  \
# 2                 P          P          P          P          P  ...
# 3                 P          P          P          P          P  ...
# 4                 P          P          P          P          A  ...
# 5                 P          A          P          P          P  ...
#
#          2017-08-11 2017-08-16 Present Absent  %SUB %SUB2 %SUB3 %SUB4  %SUB5
# Roll No.
# 1                 P          A      12      5  71.0  82.0  65.0  71.0   76.0  \
# 2                 P          A      16      1  94.0  76.0  71.0  59.0   71.0
# 3                 P          P      16      1  94.0  94.0  88.0  59.0   65.0
# 4                 P          A      13      4  76.0  76.0  88.0  76.0   88.0
# 5                 P          A      13      4  76.0  94.0  82.0  82.0   76.0
#
#           %AVG
# Roll No.
# 1         73.0
# 2         74.2
# 3         80.0
# 4         80.8
# 5         82.0
#
# [5 rows x 26 columns]
