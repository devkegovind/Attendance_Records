# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("D:\Downloads\Roll Call SE, TE _ BE Mech AY 2017-18.xlsx")

# %%
df
# Out:
#     Roll No.               Name of Student
# 0          1         AIGALIKAR GIRI SUDHIR
# 1          2         APALE SAHIL JAYANTRAO
# 2          3                    ARPIT SHAH
# 3          4         BANDGAR AKSHAY SAMPAT
# 4          5         BHUWAD SANKET SANTOSH
# ..       ...                           ...
# 59        60    SALUNKE SHUBHAM BHASKARRAO
# 60        61  WATPADE SHUBHAM DNYANESHWAR
# 61        62     SWARALI SADASHIV KHADTARE
# 62        63          YADAV DHANESH TANAJI
# 63        64    PATIL PULKESHI BHALCHANDRA
#
# [64 rows x 2 columns]

# %%
df['Name of Student'] = [i.title() for i in df['Name of Student']]

# %%
df.head()
# Out:
#    Roll No.        Name of Student
# 0         1  Aigalikar Giri Sudhir
# 1         2  Apale Sahil Jayantrao
# 2         3             Arpit Shah
# 3         4  Bandgar Akshay Sampat
# 4         5  Bhuwad Sanket Santosh

# %%
import random
import pandas as pd
import numpy as np
import datetime
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

def te_students_attendance112(n, start_date, end_date):
    
    students = range(n)
    
    cal = USFederalHolidayCalendar()
    holidays = cal.holidays(start=start_date, end=end_date)
    
    custom_business_day = CustomBusinessDay(weekmask='Tue Wed Thu Fri', holidays=holidays)

    date_range = pd.date_range(start=start_date, end=end_date, freq=custom_business_day)
    
    attendance_records1 = {}
    
    for student in students:
        attendance_records1[student] = []
        
        for day in date_range:
            attendance_records1[student].append('P' if random.random() < 0.85 else 'A')
                
    df = pd.DataFrame.from_dict(attendance_records1, orient='index', columns=date_range)
    df['Present'] = df.apply(lambda x: x[x == 'P'].count(), axis=1)
    df['Absent'] = df.apply(lambda x: x[x == 'A'].count(), axis=1)
    df['%Att'] = round(df['Present'] / len(date_range) * 100,2)
    df['UT1'] = [random.randint(10,30) for i in range(0,n)]
    df['PREL'] = [random.randint(26, 65) for i in range(0, n)]
     
    return df

# %%
df11 = te_students_attendance112(64, '2017-06-15', '2017-09-29')

# %%
df11.head()
# Out:
#   2017-06-15 00:00:00 2017-06-16 00:00:00 2017-06-20 00:00:00
# 0                   P                   P                   P  \
# 1                   P                   P                   P
# 2                   P                   P                   P
# 3                   P                   P                   A
# 4                   P                   P                   A
#
#   2017-06-21 00:00:00 2017-06-22 00:00:00 2017-06-23 00:00:00
# 0                   A                   P                   P  \
# 1                   A                   P                   P
# 2                   P                   P                   P
# 3                   A                   P                   P
# 4                   P                   P                   P
#
#   2017-06-27 00:00:00 2017-06-28 00:00:00 2017-06-29 00:00:00
# 0                   P                   P                   P  \
# 1                   P                   P                   P
# 2                   P                   P                   P
# 3                   A                   P                   P
# 4                   P                   P                   P
#
#   2017-06-30 00:00:00  ... 2017-09-22 00:00:00 2017-09-26 00:00:00
# 0                   P  ...                   A                   P  \
# 1                   A  ...                   P                   P
# 2                   P  ...                   P                   A
# 3                   P  ...                   P                   P
# 4                   P  ...                   A                   A
#
#   2017-09-27 00:00:00 2017-09-28 00:00:00 2017-09-29 00:00:00 Present Absent
# 0                   P                   P                   P      53      8  \
# 1                   A                   P                   A      49     12
# 2                   P                   P                   P      52      9
# 3                   P                   P                   P      47     14
# 4                   P                   P                   P      52      9
#
#     %Att UT1 PREL
# 0  86.89  17   46
# 1  80.33  30   36
# 2  85.25  23   56
# 3  77.05  25   56
# 4  85.25  12   54
#
# [5 rows x 66 columns]

# %%
df11.loc[:,:'PREL']
# Out:
#    2017-06-15 00:00:00 2017-06-16 00:00:00 2017-06-20 00:00:00
# 0                    P                   P                   P  \
# 1                    P                   P                   P
# 2                    P                   P                   P
# 3                    P                   P                   A
# 4                    P                   P                   A
# ..                 ...                 ...                 ...
# 59                   P                   A                   P
# 60                   P                   P                   P
# 61                   P                   P                   P
# 62                   P                   P                   P
# 63                   P                   P                   P
#
#    2017-06-21 00:00:00 2017-06-22 00:00:00 2017-06-23 00:00:00
# 0                    A                   P                   P  \
# 1                    A                   P                   P
# 2                    P                   P                   P
# 3                    A                   P                   P
# 4                    P                   P                   P
# ..                 ...                 ...                 ...
# 59                   P                   A                   P
# 60                   P                   P                   P
# 61                   P                   P                   P
# 62                   P                   P                   P
# 63                   P                   P                   P
#
#    2017-06-27 00:00:00 2017-06-28 00:00:00 2017-06-29 00:00:00
# 0                    P                   P                   P  \
# 1                    P                   P                   P
# 2                    P                   P                   P
# 3                    A                   P                   P
# 4                    P                   P                   P
# ..                 ...                 ...                 ...
# 59                   P                   P                   P
# 60                   P                   P                   P
# 61                   A                   P                   P
# 62                   P                   P                   P
# 63                   P                   A                   P
#
#    2017-06-30 00:00:00  ... 2017-09-22 00:00:00 2017-09-26 00:00:00
# 0                    P  ...                   A                   P  \
# 1                    A  ...                   P                   P
# 2                    P  ...                   P                   A
# 3                    P  ...                   P                   P
# 4                    P  ...                   A                   A
# ..                 ...  ...                 ...                 ...
# 59                   P  ...                   P                   P
# 60                   P  ...                   A                   P
# 61                   P  ...                   P                   P
# 62                   P  ...                   A                   P
# 63                   P  ...                   A                   P
#
#    2017-09-27 00:00:00 2017-09-28 00:00:00 2017-09-29 00:00:00 Present Absent
# 0                    P                   P                   P      53      8  \
# 1                    A                   P                   A      49     12
# 2                    P                   P                   P      52      9
# 3                    P                   P                   P      47     14
# 4                    P                   P                   P      52      9
# ..                 ...                 ...                 ...     ...    ...
# 59                   P                   P                   P      54      7
# 60                   P                   P                   A      53      8
# 61                   P                   P                   P      54      7
# 62                   P                   P                   P      54      7
# 63                   P                   P                   P      54      7
#
#      %Att UT1 PREL
# 0   86.89  17   46
# 1   80.33  30   36
# 2   85.25  23   56
# 3   77.05  25   56
# 4   85.25  12   54
# ..    ...  ..  ...
# 59  88.52  24   46
# 60  86.89  29   34
# 61  88.52  28   65
# 62  88.52  23   52
# 63  88.52  17   65
#
# [64 rows x 66 columns]

# %%
Final_df = pd.concat([df, df11.loc[:,:'PREL']], axis = 1)

# %%
Final_df
# Out:
#     Roll No.               Name of Student 2017-06-15 00:00:00
# 0          1         Aigalikar Giri Sudhir                   P  \
# 1          2         Apale Sahil Jayantrao                   P
# 2          3                    Arpit Shah                   P
# 3          4         Bandgar Akshay Sampat                   P
# 4          5         Bhuwad Sanket Santosh                   P
# ..       ...                           ...                 ...
# 59        60    Salunke Shubham Bhaskarrao                   P
# 60        61  Watpade Shubham Dnyaneshwar                    P
# 61        62     Swarali Sadashiv Khadtare                   P
# 62        63          Yadav Dhanesh Tanaji                   P
# 63        64    Patil Pulkeshi Bhalchandra                   P
#
#    2017-06-16 00:00:00 2017-06-20 00:00:00 2017-06-21 00:00:00
# 0                    P                   P                   A  \
# 1                    P                   P                   A
# 2                    P                   P                   P
# 3                    P                   A                   A
# 4                    P                   A                   P
# ..                 ...                 ...                 ...
# 59                   A                   P                   P
# 60                   P                   P                   P
# 61                   P                   P                   P
# 62                   P                   P                   P
# 63                   P                   P                   P
#
#    2017-06-22 00:00:00 2017-06-23 00:00:00 2017-06-27 00:00:00
# 0                    P                   P                   P  \
# 1                    P                   P                   P
# 2                    P                   P                   P
# 3                    P                   P                   A
# 4                    P                   P                   P
# ..                 ...                 ...                 ...
# 59                   A                   P                   P
# 60                   P                   P                   P
# 61                   P                   P                   A
# 62                   P                   P                   P
# 63                   P                   P                   P
#
#    2017-06-28 00:00:00  ... 2017-09-22 00:00:00 2017-09-26 00:00:00
# 0                    P  ...                   A                   P  \
# 1                    P  ...                   P                   P
# 2                    P  ...                   P                   A
# 3                    P  ...                   P                   P
# 4                    P  ...                   A                   A
# ..                 ...  ...                 ...                 ...
# 59                   P  ...                   P                   P
# 60                   P  ...                   A                   P
# 61                   P  ...                   P                   P
# 62                   P  ...                   A                   P
# 63                   A  ...                   A                   P
#
#    2017-09-27 00:00:00 2017-09-28 00:00:00 2017-09-29 00:00:00 Present Absent
# 0                    P                   P                   P      53      8  \
# 1                    A                   P                   A      49     12
# 2                    P                   P                   P      52      9
# 3                    P                   P                   P      47     14
# 4                    P                   P                   P      52      9
# ..                 ...                 ...                 ...     ...    ...
# 59                   P                   P                   P      54      7
# 60                   P                   P                   A      53      8
# 61                   P                   P                   P      54      7
# 62                   P                   P                   P      54      7
# 63                   P                   P                   P      54      7
#
#      %Att UT1 PREL
# 0   86.89  17   46
# 1   80.33  30   36
# 2   85.25  23   56
# 3   77.05  25   56
# 4   85.25  12   54
# ..    ...  ..  ...
# 59  88.52  24   46
# 60  86.89  29   34
# 61  88.52  28   65
# 62  88.52  23   52
# 63  88.52  17   65
#
# [64 rows x 68 columns]

# %%
Final_df.to_csv("Sem_att.csv")

# %% [markdown]
# First Monthly Attendance

# %%
m1 = te_students_attendance112(64, '2017-06-15', '2017-07-15')

# %%
first_month_atte = pd.concat([df, m1], axis=1)

# %%
first_month_atte.to_csv('First_Month_Att.csv')

# %% [markdown]
# Second Monthly Attendance

# %%
m2 = te_students_attendance112(64, '2017-07-16', '2017-08-16')

# %%
second_month_att = pd.concat([df, m2], axis=1)

# %%
second_month_att
# Out:
#     Roll No.               Name of Student 2017-07-18 00:00:00
# 0          1         Aigalikar Giri Sudhir                   P  \
# 1          2         Apale Sahil Jayantrao                   P
# 2          3                    Arpit Shah                   P
# 3          4         Bandgar Akshay Sampat                   P
# 4          5         Bhuwad Sanket Santosh                   A
# ..       ...                           ...                 ...
# 59        60    Salunke Shubham Bhaskarrao                   A
# 60        61  Watpade Shubham Dnyaneshwar                    P
# 61        62     Swarali Sadashiv Khadtare                   A
# 62        63          Yadav Dhanesh Tanaji                   P
# 63        64    Patil Pulkeshi Bhalchandra                   P
#
#    2017-07-19 00:00:00 2017-07-20 00:00:00 2017-07-21 00:00:00
# 0                    P                   P                   P  \
# 1                    P                   P                   P
# 2                    P                   P                   P
# 3                    P                   P                   A
# 4                    P                   P                   P
# ..                 ...                 ...                 ...
# 59                   P                   P                   P
# 60                   P                   P                   P
# 61                   P                   P                   P
# 62                   P                   P                   P
# 63                   P                   P                   P
#
#    2017-07-25 00:00:00 2017-07-26 00:00:00 2017-07-27 00:00:00
# 0                    P                   A                   A  \
# 1                    P                   P                   P
# 2                    P                   P                   A
# 3                    P                   P                   P
# 4                    P                   P                   P
# ..                 ...                 ...                 ...
# 59                   P                   P                   P
# 60                   P                   P                   P
# 61                   P                   P                   A
# 62                   P                   P                   P
# 63                   P                   P                   P
#
#    2017-07-28 00:00:00  ... 2017-08-09 00:00:00 2017-08-10 00:00:00
# 0                    A  ...                   P                   P  \
# 1                    P  ...                   P                   P
# 2                    P  ...                   A                   P
# 3                    P  ...                   P                   P
# 4                    A  ...                   P                   P
# ..                 ...  ...                 ...                 ...
# 59                   P  ...                   A                   P
# 60                   P  ...                   P                   P
# 61                   P  ...                   P                   A
# 62                   P  ...                   P                   P
# 63                   P  ...                   P                   A
#
#    2017-08-11 00:00:00 2017-08-15 00:00:00 2017-08-16 00:00:00 Present Absent
# 0                    P                   A                   P      14      4  \
# 1                    P                   P                   P      18      0
# 2                    P                   P                   A      15      3
# 3                    P                   P                   P      17      1
# 4                    P                   P                   P      15      3
# ..                 ...                 ...                 ...     ...    ...
# 59                   P                   P                   A      13      5
# 60                   P                   P                   P      17      1
# 61                   P                   P                   P      14      4
# 62                   P                   P                   P      17      1
# 63                   P                   P                   P      16      2
#
#       %Att UT1 PREL
# 0    77.78  29   47
# 1   100.00  12   41
# 2    83.33  12   34
# 3    94.44  23   49
# 4    83.33  19   41
# ..     ...  ..  ...
# 59   72.22  25   47
# 60   94.44  22   55
# 61   77.78  12   42
# 62   94.44  21   54
# 63   88.89  10   32
#
# [64 rows x 25 columns]

# %%
second_month_att.to_csv('Second_Month_Att.csv')
