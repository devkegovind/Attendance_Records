# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("D:\Downloads\AY 2020-21.xlsx")
df.head()
# Out:
#    Roll No          Name of Student
# 0     3301   Liman Abhijeet Shivaji
# 1     3302  Adlinge Akshay Hanamant
# 2     3303    Awasare Rohan Krishna
# 3     3304    Bachal Shubham Vishal
# 4     3305        Bagul Akash Jagan

# %% [markdown]
# **BATCH A PRACTICAL ATTENDANCE**

# %%
import random
import pandas as pd
import numpy as np
import datetime
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
import pandas as pd
import holidays

def lab_students_attendance_a(n, start_year, start_date, end_date):
    
    students = range(n)
    
    # Set the start and end dates
    start_date = pd.Timestamp(start_date)
    end_date = pd.Timestamp(end_date)

    # Get the Indian holidays for 2021
    indian_holidays = holidays.IND(years=[start_year, start_year+0])

    custom_business_day = CustomBusinessDay(weekmask='Mon', holidays=indian_holidays)

    # Generate a range of dates between the start and end dates
    date_range = pd.date_range(start=start_date, end=end_date, freq=custom_business_day).strftime("%Y-%m-%d")
   
    
    practical_attendance = {}

    for student in students:       
        
        practical_attendance[student] = []
        
                
        for day in date_range:
            practical_attendance[student].append('P' if random.random() < 0.9 else 'A')
            
               
    df31 = pd.DataFrame.from_dict(practical_attendance, orient='index', columns=date_range)  
    
    df31['Present'] = df31.apply(lambda x: x[x == 'P'].count(), axis=1)
    df31['Absent'] = df31.apply(lambda x: x[x == 'A'].count(), axis=1)
    df31['%Att'] = round(df31['Present'] /len(date_range) * 100)    
    df31['MARKS1'] = [random.randint(6,10) for i in range(0,n)]
    for i, date in enumerate(date_range):
        df31[f'MARKS{i+1}'] = np.random.choice(df31['MARKS1'], size=n)

            
    df = df31

    return df

# %%
batch_a = pd.concat([df[0:25], lab_students_attendance_a(25, 2021,'2021-02-08', '2021-05-15')], axis = 1)
batch_a = batch_a.set_index("Roll No")
batch_a.to_excel("D:\\Downloads\\New folder\\2020-21\\SEM_II\\BATCH_A.xlsx")
batch_a.to_csv("BATCH_A.csv")

# %% [markdown]
# **BATCH B PRACTICAL ATTENDANCE**

# %%
import random
import pandas as pd
import numpy as np
import datetime
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
import pandas as pd
import holidays

def lab_students_attendance_b(n, start_year, start_date, end_date):
    
    students = range(25,50)
    
    # Set the start and end dates
    start_date = pd.Timestamp(start_date)
    end_date = pd.Timestamp(end_date)

    # Get the Indian holidays for 2021
    indian_holidays = holidays.IND(years=[start_year, start_year+0])

    custom_business_day = CustomBusinessDay(weekmask='Wed', holidays=indian_holidays)

    # Generate a range of dates between the start and end dates
    date_range = pd.date_range(start=start_date, end=end_date, freq=custom_business_day).strftime("%Y-%m-%d")
   
    
    practical_attendance = {}

    for student in students:       
        
        practical_attendance[student] = []
        
                
        for day in date_range:
            practical_attendance[student].append('P' if random.random() < 0.9 else 'A')
            
               
    df31 = pd.DataFrame.from_dict(practical_attendance, orient='index', columns=date_range)  
    
    df31['Present'] = df31.apply(lambda x: x[x == 'P'].count(), axis=1)
    df31['Absent'] = df31.apply(lambda x: x[x == 'A'].count(), axis=1)
    df31['%Att'] = round(df31['Present'] /len(date_range) * 100)    
    df31['MARKS1'] = [random.randint(6,10) for i in range(0,n)]
    for i, date in enumerate(date_range):
        df31[f'MARKS{i+1}'] = np.random.choice(df31['MARKS1'], size=n)

            
    df = df31

    return df

# %%
batch_b = pd.concat([df[25:50], lab_students_attendance_b(25, 2021,'2021-02-08', '2021-05-15')], axis = 1)
batch_b = batch_b.set_index("Roll No")
batch_b.to_excel("D:\\Downloads\\New folder\\2020-21\\SEM_II\\BATCH_B.xlsx")
batch_b.to_csv("BATCH_B.csv")

# %% [markdown]
# **BATCH C PRACTICAL ATTENDANCE**

# %%
import random
import pandas as pd
import numpy as np
import datetime
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
import pandas as pd
import holidays

def lab_students_attendance_c(n, start_year, start_date, end_date):
    
    students = range(50,80)
    
    # Set the start and end dates
    start_date = pd.Timestamp(start_date)
    end_date = pd.Timestamp(end_date)

    # Get the Indian holidays for 2021
    indian_holidays = holidays.IND(years=[start_year, start_year+0])

    custom_business_day = CustomBusinessDay(weekmask='Fri', holidays=indian_holidays)

    # Generate a range of dates between the start and end dates
    date_range = pd.date_range(start=start_date, end=end_date, freq=custom_business_day).strftime("%Y-%m-%d")
   
    
    practical_attendance = {}

    for student in students:       
        
        practical_attendance[student] = []
        
                
        for day in date_range:
            practical_attendance[student].append('P' if random.random() < 0.9 else 'A')
            
               
    df31 = pd.DataFrame.from_dict(practical_attendance, orient='index', columns=date_range)  
    
    df31['Present'] = df31.apply(lambda x: x[x == 'P'].count(), axis=1)
    df31['Absent'] = df31.apply(lambda x: x[x == 'A'].count(), axis=1)
    df31['%Att'] = round(df31['Present'] /len(date_range) * 100)    
    df31['MARKS1'] = [random.randint(6,10) for i in range(0,n)]
    for i, date in enumerate(date_range):
        df31[f'MARKS{i+1}'] = np.random.choice(df31['MARKS1'], size=n)

            
    df = df31

    return df

# %%
batch_c = pd.concat([df[50:80], lab_students_attendance_c(30, 2021,'2021-02-08', '2021-05-15')], axis = 1)
batch_c = batch_c.set_index("Roll No")
batch_c.to_excel("D:\\Downloads\\New folder\\2020-21\\SEM_II\\BATCH_C.xlsx")
batch_c.to_csv("BATCH_C.csv")
