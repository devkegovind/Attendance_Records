# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("D:\Downloads\Roll Call SE, TE _ BE Mech AY 2020-21 (1).xlsx")

# %%
df['Name of Student'] = [i.title() for i in df['Name of Student']]

# %%
df.head()
# Out:
#    Roll No                Name of Student
# 0     4201         Kshirsagar Rohan Umesh
# 1     4202  Kshirsagar Saurabh Bhaskarrao
# 2     4203        Kulkarni Chinmay Sudhir
# 3     4204       Kulkarni Vedant Shrikant
# 4     4205          Kumkar Yadnesh Vishnu

# %%
df.shape
# Out:
# (65, 2)

# %%
df.to_csv("BE-2[20-21].csv")

# %% [markdown]
# **SEMESTER ATTENDANCE**

# %%
import random
import pandas as pd
import numpy as np
import datetime
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

def te_students_attendance11(n, start_date, end_date):
    
    students = range(n)
    
    cal = USFederalHolidayCalendar()
    holidays = cal.holidays(start=start_date, end=end_date)
    
    custom_business_day = CustomBusinessDay(weekmask='Mon Thu Fri', holidays=holidays)

    date_range = pd.date_range(start=start_date, end=end_date, freq=custom_business_day)
    
    attendance_records1 = {}
    
    for student in students:
        attendance_records1[student] = []
        
        for day in date_range:
            attendance_records1[student].append('P' if random.random() < 0.85 else 'A')
                
    df = pd.DataFrame.from_dict(attendance_records1, orient='index', columns=date_range)
    df['Present'] = df.apply(lambda x: x[x == 'P'].count(), axis=1)
    df['Absent'] = df.apply(lambda x: x[x == 'A'].count(), axis=1)
    df['%Att'] = round(df['Present'] / len(date_range) * 100,2)
    df['UT1'] = [random.randint(10,30) for i in range(0,n)]
    df['PREL'] = [random.randint(26, 65) for i in range(0, n)]
     
    return df

# %%
sem_att = pd.concat([df, te_students_attendance11(df.shape[0], '2020-08-06', '2020-10-29')],axis=1)
sem_att
# Out:
#     Roll No                Name of Student 2020-08-06 00:00:00
# 0      4201         Kshirsagar Rohan Umesh                   P  \
# 1      4202  Kshirsagar Saurabh Bhaskarrao                   P
# 2      4203        Kulkarni Chinmay Sudhir                   P
# 3      4204       Kulkarni Vedant Shrikant                   P
# 4      4205          Kumkar Yadnesh Vishnu                   A
# ..      ...                            ...                 ...
# 60     4261      Kulkarni Sushil Nandkumar                   P
# 61     4262      Saurabh Parmeshwar Borude                   P
# 62     4263      Suyesh Laxmikant Pillewar                   P
# 63     4264        Jungade Pranav Prashant                   P
# 64     4265                 Sanjay  Pandey                   P
#
#    2020-08-07 00:00:00 2020-08-10 00:00:00 2020-08-13 00:00:00
# 0                    P                   A                   P  \
# 1                    P                   P                   A
# ...

# %% [markdown]
# **SEMESTER ATTENDANCE**

# %%
sem_att = pd.concat([df, te_students_attendance123(len(df), '2020-08-06', '2020-10-29')],axis = 1)
sem_att.to_csv("Sem_Att.csv")

# %% [markdown]
# **FIRST MONTH ATTENDANCE**

# %%
month_1 = pd.concat([df, te_students_attendance11(len(df), '2020-08-06', '2020-09-06')],axis = 1)
month_1.to_csv("Fisrt_Month_Att.csv")

# %%
month_1.head()
# Out:
#    Roll No                Name of Student 2020-08-06 00:00:00
# 0     4201         Kshirsagar Rohan Umesh                   P  \
# 1     4202  Kshirsagar Saurabh Bhaskarrao                   A
# 2     4203        Kulkarni Chinmay Sudhir                   P
# 3     4204       Kulkarni Vedant Shrikant                   P
# 4     4205          Kumkar Yadnesh Vishnu                   A
#
#   2020-08-07 00:00:00 2020-08-10 00:00:00 2020-08-13 00:00:00
# 0                   P                   P                   P  \
# 1                   P                   P                   P
# 2                   P                   A                   P
# 3                   P                   P                   P
# 4                   P                   P                   P
#
#   2020-08-14 00:00:00 2020-08-17 00:00:00 2020-08-20 00:00:00
# 0                   P                   P                   P  \
# 1                   P                   P                   P
# ...

# %%
month_2 = pd.concat([df, te_students_attendance11(len(df), '2020-09-07', '2020-10-07')],axis = 1)
month_2.to_csv("Second_Month_Att.csv")

# %%
month_2.head()
# Out:
#    Roll No                Name of Student 2020-09-10 00:00:00
# 0     4201         Kshirsagar Rohan Umesh                   P  \
# 1     4202  Kshirsagar Saurabh Bhaskarrao                   P
# 2     4203        Kulkarni Chinmay Sudhir                   P
# 3     4204       Kulkarni Vedant Shrikant                   A
# 4     4205          Kumkar Yadnesh Vishnu                   P
#
#   2020-09-11 00:00:00 2020-09-14 00:00:00 2020-09-17 00:00:00
# 0                   P                   P                   P  \
# 1                   P                   P                   A
# 2                   P                   P                   P
# 3                   P                   P                   P
# 4                   P                   P                   P
#
#   2020-09-18 00:00:00 2020-09-21 00:00:00 2020-09-24 00:00:00
# 0                   P                   P                   P  \
# 1                   P                   P                   P
# ...
