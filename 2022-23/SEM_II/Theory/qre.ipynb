# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("D:\\Downloads\\New folder\\2022-23\\BE-3.xlsx")
df
# Out:
#    Roll No.               Name of Students
# 0     B5064         NATUSKAR YUVRAJ MILIND
# 1     B5065           NAVLAKHE NAKUL SUNIL
# 2     B5066          NIKALJE RUTVIK RAJESH
# 3     B5067         PANDURE SHUBHAM SANJAY
# 4     B5068           PATEL PARVEZ DILAWAR
# 5     B5069         PATIL CHETAN DEEPENDRA
# 6     B5070             PATIL DARSHAN ANIL
# 7     B5071              PATIL GEET HARISH
# 8     B5072           PATIL PRASAD SHIVAJI
# 9     B5073    PATIL PRASHANT PANDHARINATH
# 10    B5074      PATIL PREMSING PRITAMSING
# 11    B5075           PATIL RADHEY SUBHASH
# 12    B5076         PATIL SUSHANT SAMBHAJI
# 13    B5077        PATIL YADNYESH RAVIKANT
# 14    B5078            PETHE SHARAD LAXMAN
# 15    B5079                  PRANJAL YADAV
# 16    B5080      PRATIK CHANDRAKANT JADHAV
# 17    B5081       PURNALE SWAPNIL SAMBHAJI
# 18    B5082           ROHAN PRAVIN KALWADE
# 19    B5083          SABALE AJAY BALASAHEB
# 20    B5084           SANGA NIKHIL SANJEEV
# 21    B5085          SANKET SUBHASH SHINDE
# 22    B5086       SATPUTE SHARDUL SAMBHAJI
# 23    B5087            SHINDE ANIKET MOHAN
# 24    B5088   SHINDE PRADNYA RAJENDRAKUMAR
# 25    B5089              SHINDE TEJAS ANIL
# 26    B5090                    SOHAM KODRE
# 27    B5091       SOMWANSHI KSHITIJ SANJAY
# 28    B5092         SONAWANE OMKAR JAYWANT
# 29    B5093        SONKAMBLE NAGESH BALAJI
# 30    B5094            TAMBOLI SAHIL ABDUL
# 31    B5095      THAWALE PIYUSH DATTATRAYA
# 32    B5096  TIDAKE HRISHIKESH DNYANESHWAR
# 33    B5097            TOPE VAIBHAV RAMESH
# 34    B5098       UPASANI VEDANT DHANANJAY
# 35    B5099       VISHWAJIT NAVANATH PATIL
# 36    B5100       WALVEKAR CHINMAY HANMANT
# 37    B5101            YASH RAVINDRA BANDA
# 38    B5102             ZANJE KUNAL ANKUSH
# 39    B5103         ZARKAR RUSHIKESH NITIN

# %%
df['Name of Students'] = [i.title() for i in df['Name of Students']]

# %%
df.head()
# Out:
#   Roll No.        Name of Students
# 0    B5064  Natuskar Yuvraj Milind
# 1    B5065    Navlakhe Nakul Sunil
# 2    B5066   Nikalje Rutvik Rajesh
# 3    B5067  Pandure Shubham Sanjay
# 4    B5068    Patel Parvez Dilawar

# %%
import random
import pandas as pd
import numpy as np
import datetime
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
import pandas as pd
import holidays

def sem_students_attendance(n, start_year, start_date, end_date):

    students = range(n)
    
    # Set the start and end dates
    start_date = pd.Timestamp(start_date)
    end_date = pd.Timestamp(end_date)

    # Get the Indian holidays for 2021
    indian_holidays = holidays.IND(years=[start_year, start_year+0])

    custom_business_day = CustomBusinessDay(weekmask='Mon Wed Thu', holidays=indian_holidays)

    # Generate a range of dates between the start and end dates
    date_range = pd.date_range(start=start_date, end=end_date, freq=custom_business_day).strftime('%Y-%m-%d')
    


    attendance_records1 = {}
    
    for student in students:
        attendance_records1[student] = []
        
        for day in date_range:
            attendance_records1[student].append('P' if random.random() < 0.5 else 'A')
                
    df = pd.DataFrame.from_dict(attendance_records1, orient='index', columns=date_range)
    df['Present'] = df.apply(lambda x: x[x == 'P'].count(), axis=1)
    df['Absent'] = df.apply(lambda x: x[x == 'A'].count(), axis=1)
    df['%Att'] = round(df['Present'] / len(date_range) * 100)
     
    return df

# %%
sem_students_attendance(df.shape[0], 2023, '2023-01-25', '2023-05-10')
# Out:
#    2023-01-25 2023-01-30 2023-02-01 2023-02-02 2023-02-06 2023-02-08
# 0           A          A          A          A          A          A  \
# 1           P          P          A          A          A          A
# 2           P          A          A          P          P          A
# 3           A          A          P          A          P          P
# 4           A          A          A          P          A          P
# 5           P          P          P          A          A          A
# 6           P          A          A          P          P          P
# 7           A          A          P          P          A          P
# 8           P          A          P          A          A          P
# 9           A          P          A          P          P          A
# 10          P          P          P          P          P          P
# 11          P          P          P          A          P          A
# 12          P          P          A          A          A          A
# 13          P          P          A          P          P          P
# 14          P          A          P          A          P          A
# 15          A          P          P          P          P          A
# 16          P          P          A          A          A          A
# 17          P          A          A          P          A          A
# 18          P          A          A          A          P          A
# 19          A          P          P          P          A          A
# 20          P          A          A          P          P          A
# 21          A          A          A          P          P          P
# 22          P          A          A          A          A          P
# 23          P          P          A          P          A          A
# 24          P          P          P          A          A          P
# 25          A          P          P          A          A          P
# 26          P          P          P          A          A          P
# 27          A          A          P          P          P          A
# 28          A          P          A          P          A          A
# 29          A          P          P          P          P          A
# 30          P          A          P          A          A          P
# 31          A          P          A          P          A          A
# 32          A          A          A          P          P          P
# 33          A          P          P          A          P          P
# 34          P          A          P          A          P          P
# 35          P          P          P          P          A          A
# 36          P          P          A          P          P          P
# 37          A          P          P          P          P          A
# 38          A          A          A          P          A          P
# 39          P          A          P          A          A          P
#
#    2023-02-09 2023-02-13 2023-02-15 2023-02-16  ... 2023-04-24 2023-04-26
# 0           P          P          P          A  ...          P          A  \
# 1           P          P          P          A  ...          A          P
# 2           A          A          A          A  ...          A          P
# 3           A          P          A          A  ...          P          A
# 4           P          A          A          P  ...          A          P
# 5           P          P          A          P  ...          A          P
# 6           P          A          P          P  ...          P          A
# 7           P          A          P          P  ...          P          A
# 8           A          P          A          A  ...          A          A
# 9           P          A          P          P  ...          A          A
# 10          A          A          P          A  ...          A          P
# 11          A          A          P          A  ...          P          A
# 12          A          A          A          A  ...          P          A
# 13          A          A          P          A  ...          A          P
# 14          P          A          A          P  ...          A          P
# 15          P          A          A          A  ...          A          A
# 16          P          A          P          P  ...          A          A
# 17          A          A          A          P  ...          A          P
# 18          P          A          A          P  ...          P          P
# 19          A          A          A          A  ...          A          P
# 20          P          P          A          P  ...          P          P
# 21          P          P          A          P  ...          P          P
# 22          P          P          P          P  ...          A          A
# 23          A          P          A          A  ...          P          A
# 24          A          P          P          A  ...          A          A
# 25          P          A          A          P  ...          A          P
# 26          A          A          A          A  ...          A          A
# 27          A          A          A          A  ...          A          P
# 28          P          A          A          A  ...          P          P
# 29          A          P          P          A  ...          A          P
# 30          A          P          A          P  ...          A          A
# 31          P          P          A          P  ...          P          P
# 32          P          A          A          P  ...          P          A
# 33          P          P          P          A  ...          A          A
# 34          P          P          P          A  ...          P          A
# 35          P          A          A          A  ...          P          A
# 36          P          P          P          A  ...          P          A
# 37          P          A          P          A  ...          P          P
# 38          A          A          A          P  ...          A          P
# 39          P          A          A          A  ...          P          A
#
#    2023-04-27 2023-05-03 2023-05-04 2023-05-08 2023-05-10 Present Absent  %Att
# 0           P          P          P          A          P      22     21  51.0
# 1           A          P          P          A          P      20     23  47.0
# 2           P          A          A          P          P      18     25  42.0
# 3           P          A          P          P          P      21     22  49.0
# 4           A          P          A          P          A      19     24  44.0
# 5           P          A          A          A          P      23     20  53.0
# 6           P          P          P          A          A      24     19  56.0
# 7           P          P          A          P          A      20     23  47.0
# 8           A          P          P          P          P      20     23  47.0
# 9           P          A          P          A          P      20     23  47.0
# 10          P          P          P          A          A      23     20  53.0
# 11          A          P          P          A          A      21     22  49.0
# 12          P          P          P          P          P      20     23  47.0
# 13          A          A          A          A          A      20     23  47.0
# 14          P          A          P          A          P      23     20  53.0
# 15          P          P          P          P          A      24     19  56.0
# 16          P          A          A          A          A      21     22  49.0
# 17          P          P          P          A          P      20     23  47.0
# 18          A          P          P          P          A      22     21  51.0
# 19          A          A          P          A          P      19     24  44.0
# 20          A          P          A          A          A      24     19  56.0
# 21          P          P          P          A          A      22     21  51.0
# 22          A          A          P          P          A      23     20  53.0
# 23          P          P          P          A          P      19     24  44.0
# 24          A          A          P          A          A      18     25  42.0
# 25          P          P          A          P          A      23     20  53.0
# 26          A          A          A          P          A      15     28  35.0
# 27          P          P          A          A          A      20     23  47.0
# 28          P          A          P          A          A      18     25  42.0
# 29          A          A          P          P          A      20     23  47.0
# 30          P          A          A          A          P      19     24  44.0
# 31          A          P          P          A          P      24     19  56.0
# 32          P          P          A          A          A      23     20  53.0
# 33          A          P          P          P          P      28     15  65.0
# 34          A          P          A          P          P      21     22  49.0
# 35          P          P          A          A          P      26     17  60.0
# 36          P          A          A          A          P      27     16  63.0
# 37          A          P          P          A          P      26     17  60.0
# 38          P          A          P          A          A      19     24  44.0
# 39          P          A          P          P          A      19     24  44.0
#
# [40 rows x 46 columns]

# %%
d1 = pd.concat([df, sem_students_attendance(df.shape[0], 2023, '2023-01-25', '2023-05-10')], axis = 1)
d1 = d1.set_index("Roll No.")
d1.to_excel("D:\\Downloads\\New folder\\2022-23\\SEM_ATT1.xlsx")
d1.to_csv("SEM_ATT.csv")
